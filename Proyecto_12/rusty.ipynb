# %% [markdown]
# # Modelo para Rusty Bargain

# %% [markdown]
# ## Índice <a id='back'></a>
# * [Introducción](#intro)
# * [Etapa 1. Descripción y preprocesamiento de los datos](#data_review)
#     * [1. 1. Información general de los datos](#data_review_data)
#     * [1. 2. Valores problemáticos](#data_review_trouble)
#     * [1. 3. Valores ausentes](#data_review_missing)
#     * [1. 4. Conclusiones](#data_review_conclusions)
# * [Etapa 2. Entrenamiento del modelo](#data_model)
#     * [2. 1. Regresión lineal](#data_model_linear)
#     * [2. 2. Árbol de decisión](#data_model_tree)
#     * [2. 3. Bosque aleatorio](#data_model_forest)
#     * [2. 4. CatBoost](#data_model_catboost)
#     * [2. 5. LightGBM](#data_model_lightgbm)
#     * [2. 6. Conclusiones](#data_model_conclusions)
# * [Etapa 3. Análisis del modelo](#data_analysis)
# * [Etapa 4. Conclusión general](#data_conclusion)

# %% [markdown]
# ## Introducción <a id='intro'></a>
#
# Rusty Bargain es un servicio de venta de coches de segunda mano que está desarrollando una app para atraer a nuevos clientes. Con la app, se puede averiguar rápidamente el valor de mercado de un coche. Se tiene acceso al historial, especificaciones técnicas, versiones de equipamiento y precios. El objetivo es crear un modelo que determine el valor de mercado, considerando los siguientes puntos:
#
# - Calidad de la predicción.
# - Velocidad de la predicción.
# - Tiempo requerido para el entrenamiento.
#
# Los datos se almacenan en el archivo `/datasets/car_dat.csv`. Como se desconoce la calidad de los datos, el proyecto consistirá en cuatro etapas:
#
# 1. Descripción y preprocesamiento de los datos.
# 2. Entrenamiento del modelo.
# 3. Análisis del modelo.
# 4. Conclusión general.
#
# [Volver a Contenidos](#back)

# %% [markdown]
# ## Etapa 1. Descripción y preprocesamiento de los datos <a id='data_review'></a>
#
# Se importan las librerías necesarias.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, make_scorer
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor
import time

# %% [markdown]
# Se leerá el archivo y se guardará en la variable `data`.

# %%
try:
    data = pd.read_csv('car_data.csv')
except:
    data = pd.read_csv('/datasets/car_data.csv')

# %% [markdown]
# ### 1. 1. Información general de los datos <a id='data_review_data'></a>
#
# Se imprimirá la información general de `data` y las primeras 10 filas de éste.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354369 entries, 0 to 354368
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   DateCrawled        354369 non-null  object
#  1   Price              354369 non-null  int64
#  2   VehicleType        316879 non-null  object
#  3   RegistrationYear   354369 non-null  int64
#  4   Gearbox            334536 non-null  object
#  5   Power              354369 non-null  int64
#  6   Model              334664 non-null  object
#  7   Mileage            354369 non-null  int64
#  8   RegistrationMonth  354369 non-null  int64
#  9   FuelType           321474 non-null  object
#  10  Brand              354369 non-null  object
#  11  NotRepaired        283215 non-null  object
#  12  DateCreated        354369 non-null  object
#  13  NumberOfPictures   354369 non-null  int64
#  14  PostalCode         354369 non-null  int64
#  15  LastSeen           354369 non-null  object
# dtypes: int64(7), object(9)
# memory usage: 43.3+ MB

# %%
data.head(10)
# Out:
#         DateCrawled  Price  VehicleType  RegistrationYear Gearbox  Power  \
# 0  24/03/2016 11:52    480          NaN              1993  manual      0
# 1  24/03/2016 10:58  18300        coupe              2011  manual    190
# 2  14/03/2016 12:52   9800          suv              2004    auto    163
# 3  17/03/2016 16:54   1500        small              2001  manual     75
# 4  31/03/2016 17:25   3600        small              2008  manual     69
# 5  04/04/2016 17:36    650        sedan              1995  manual    102
# 6  01/04/2016 20:48   2200  convertible              2004  manual    109
# 7  21/03/2016 18:54      0        sedan              1980  manual     50
# 8  04/04/2016 23:42  14500          bus              2014  manual    125
# 9  17/03/2016 10:53    999        small              1998  manual    101
#
#      Model  Mileage  RegistrationMonth  FuelType       Brand NotRepaired  \
# 0     golf   150000                  0    petrol  volkswagen         NaN
# 1      NaN   125000                  5  gasoline        audi         yes
# 2    grand   125000                  8  gasoline        jeep         NaN
# 3     golf   150000                  6    petrol  volkswagen          no
# 4    fabia    90000                  7  gasoline       skoda          no
# 5      3er   150000                 10    petrol         bmw         yes
# 6  2_reihe   150000                  8    petrol     peugeot          no
# 7    other    40000                  7    petrol  volkswagen          no
# 8    c_max    30000                  8    petrol        ford         NaN
# 9     golf   150000                  0       NaN  volkswagen         NaN
#
#         DateCreated  NumberOfPictures  PostalCode          LastSeen
# 0  24/03/2016 00:00                 0       70435  07/04/2016 03:16
# 1  24/03/2016 00:00                 0       66954  07/04/2016 01:46
# 2  14/03/2016 00:00                 0       90480  05/04/2016 12:47
# 3  17/03/2016 00:00                 0       91074  17/03/2016 17:40
# 4  31/03/2016 00:00                 0       60437  06/04/2016 10:17
# 5  04/04/2016 00:00                 0       33775  06/04/2016 19:17
# 6  01/04/2016 00:00                 0       67112  05/04/2016 18:18
# 7  21/03/2016 00:00                 0       19348  25/03/2016 16:47
# 8  04/04/2016 00:00                 0       94505  04/04/2016 23:42
# 9  17/03/2016 00:00                 0       27472  31/03/2016 17:17

# %% [markdown]
# El dataframe contiene 354,369 filas y 16 columnas, las cuales son:
#
# 1. `DateCrawled` - fecha en la que se descargó el perfil de la base de datos.
# 2. `Price` - precio en euros.
# 3. `VehicleType` - tipo de carrocería del vehículo.
# 4. `RegistrationYear` - año de matriculación del vehículo.
# 5. `Gearbox` - tipo de caja de cambios.
# 6. `Power` - potencia del vehículo (caballo de vapor, CV).
# 7. `Model` - modelo del vehículo.
# 8. `Mileage` - kilometraje (medido en km de acuerdo con las especificidades regionales del conjunto de datos).
# 9. `RegirtrationMonth` - mes de matriculación del vehículo.
# 10. `FuelType` - tipo de combustible.
# 11. `Brand` - marca del vehículo.
# 12. `NotRepaired` - vehículo con o sin reparación.
# 13. `DateCreated` - fecha de creación de perfil.
# 14. `NumberOfPictures` - cantidad de fotos del vehículo.
# 15. `PostalCode` - código postal del propietario del perfil (usuario).
# 16. `LastSeen` - fecha de la última vez que el usuario estuvo activo.
#
# Se observa que las columnas no están nombradas en la convención estándar. Los datos de las columnas `DateCrawled`, `DateCreated` y `LastSeen` pueden ser cambiados a formato fecha. Existen valores ausentes en 5 columnas y al menos, la fila 7 contiene el valor 0 en el precio (columna que es el objetivo del modelo), es decir, pueden existir valores problemáticos en las columnas.
#
# A continuación, se estandarizarán los nombres de las columnas.

# %%
data.columns
# Out:
# Index(['DateCrawled', 'Price', 'VehicleType', 'RegistrationYear', 'Gearbox',
#        'Power', 'Model', 'Mileage', 'RegistrationMonth', 'FuelType', 'Brand',
#        'NotRepaired', 'DateCreated', 'NumberOfPictures', 'PostalCode',
#        'LastSeen'],
#       dtype='object')

# %%
data.columns = [
    'date_crawled', 'price', 'vehicle_type', 'registration_year', 'gearbox', 'power', 'model', 'mileage',
    'registration_month', 'fuel_type', 'brand', 'not_repaired', 'date_created', 'number_of_pictures',
    'postal_code', 'last_seen'
]
data.columns
# Out:
# Index(['date_crawled', 'price', 'vehicle_type', 'registration_year', 'gearbox',
#        'power', 'model', 'mileage', 'registration_month', 'fuel_type', 'brand',
#        'not_repaired', 'date_created', 'number_of_pictures', 'postal_code',
#        'last_seen'],
#       dtype='object')

# %% [markdown]
# Se cambiará el formato de las tres columnas que contienen fechas.

# %%
for item in ['date_crawled', 'date_created', 'last_seen']:
    data[item] = pd.to_datetime(data[item], format='%d/%m/%Y %H:%M')
    
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354369 entries, 0 to 354368
# Data columns (total 16 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   date_crawled        354369 non-null  datetime64[ns]
#  1   price               354369 non-null  int64
#  2   vehicle_type        316879 non-null  object
#  3   registration_year   354369 non-null  int64
#  4   gearbox             334536 non-null  object
#  5   power               354369 non-null  int64
#  6   model               334664 non-null  object
#  7   mileage             354369 non-null  int64
#  8   registration_month  354369 non-null  int64
#  9   fuel_type           321474 non-null  object
#  10  brand               354369 non-null  object
#  11  not_repaired        283215 non-null  object
#  12  date_created        354369 non-null  datetime64[ns]
#  13  number_of_pictures  354369 non-null  int64
#  14  postal_code         354369 non-null  int64
#  15  last_seen           354369 non-null  datetime64[ns]
# dtypes: datetime64[ns](3), int64(7), object(6)
# memory usage: 43.3+ MB

# %% [markdown]
# Se han cambiado el formato de las columnas que contienen fechas. Estas columnas funcionan como identificadores únicos. Se imprimirá la cantidad de filas duplicadas.

# %%
print(data.duplicated().sum())
# Out:
# 262

# %% [markdown]
# Esta cantidad no representa ni el 1% de la cantidad total de filas que se tienen. Por esta razón, se decide eliminarlas.

# %%
data = data.drop_duplicates().reset_index(drop=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354107 entries, 0 to 354106
# Data columns (total 16 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   date_crawled        354107 non-null  datetime64[ns]
#  1   price               354107 non-null  int64
#  2   vehicle_type        316623 non-null  object
#  3   registration_year   354107 non-null  int64
#  4   gearbox             334277 non-null  object
#  5   power               354107 non-null  int64
#  6   model               334406 non-null  object
#  7   mileage             354107 non-null  int64
#  8   registration_month  354107 non-null  int64
#  9   fuel_type           321218 non-null  object
#  10  brand               354107 non-null  object
#  11  not_repaired        282962 non-null  object
#  12  date_created        354107 non-null  datetime64[ns]
#  13  number_of_pictures  354107 non-null  int64
#  14  postal_code         354107 non-null  int64
#  15  last_seen           354107 non-null  datetime64[ns]
# dtypes: datetime64[ns](3), int64(7), object(6)
# memory usage: 43.2+ MB

# %% [markdown]
# En la siguiente sección se investigará valores problemáticos de las columnas y se decidirá el mejor tratamiento.
#
# [Volver a Contenidos](#back)

# %% [markdown]
# ### 1. 2. Valores problemáticos <a id='data_review_trouble'></a>
#
# Primero se investigarán las columnas con datos numéricos.

# %%
print(data.describe())
# Out:
#                price  registration_year          power        mileage  \
# count  354107.000000      354107.000000  354107.000000  354107.000000
# mean     4416.433287        2004.235355     110.089651  128211.811684
# std      4514.338584          90.261168     189.914972   37906.590101
# min         0.000000        1000.000000       0.000000    5000.000000
# 25%      1050.000000        1999.000000      69.000000  125000.000000
# 50%      2700.000000        2003.000000     105.000000  150000.000000
# 75%      6400.000000        2008.000000     143.000000  150000.000000
# max     20000.000000        9999.000000   20000.000000  150000.000000
#
#        registration_month  number_of_pictures    postal_code
# count       354107.000000            354107.0  354107.000000
# mean             5.714182                 0.0   50507.145030
# std              3.726682                 0.0   25784.212094
# min              0.000000                 0.0    1067.000000
# 25%              3.000000                 0.0   30165.000000
# 50%              6.000000                 0.0   49406.000000
# 75%              9.000000                 0.0   71083.000000
# max             12.000000                 0.0   99998.000000

# %% [markdown]
# Las columnas con datos problemáticos son:
#  - `price`, contiene filas con valor igual a 0.
#  - `registration_year` contiene años que salen del rango de la historia del automóvil (de 1886 a 2023).
#  - `registration_month` contiene filas con mes igual 0 (el rango es entre 1 y 12).
#
# Se mostrarán los porcentajes de filas con valores problemáticas en estas dolunmas, con respecto a la cantidad total de las filas para decidir su tratamiento.

# %%
cnt_price = len(data[data['price'] == 0])
ratio_price = cnt_price / len(data)

print(f'Existen {cnt_price} filas con precio 0, esto representa un {ratio_price:.0%}')
# Out:
# Existen 10770 filas con precio 0, esto representa un 3%

# %% [markdown]
# Como solamente representan el 3% y además, es la columna objetivo del modelo, se decide eliminar estas filas.

# %%
data = data[data['price'] > 0]

# %% [markdown]
# A continuación se procede de manera similar con la columna `registration_year`.

# %%
cnt_year = len(data) - len(data[(data['registration_year'] >= 1886) & (data['registration_year'] <= 2023)])
ratio_year = cnt_year / len(data)

print(f'Existen {cnt_year} filas con años absurdos, esto representa un {ratio_year:.0%}')
# Out:
# Existen 139 filas con años absurdos, esto representa un 0%

# %% [markdown]
# Se eliminarán estas filas, pues representan menos del 1%.

# %%
data = data[(data['registration_year'] >= 1886) & (data['registration_year'] <= 2023)]

# %% [markdown]
# Se procede de manera similar con la columna `registration_month`.

# %%
cnt_month = len(data[data['registration_month'] == 0])
ratio_month = cnt_month / len(data)

print(f'Existen {cnt_month} filas con mes igual a 0, esto representa un {ratio_month:.0%}')
# Out:
# Existen 32768 filas con mes igual a 0, esto representa un 10%

# %% [markdown]
# Esta filas representan un 10% y no hay manera de saber el mes de registro por lo que se decide elimnarlas.

# %%
data = data[data['registration_month'] > 0].reset_index(drop=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310430 entries, 0 to 310429
# Data columns (total 16 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   date_crawled        310430 non-null  datetime64[ns]
#  1   price               310430 non-null  int64
#  2   vehicle_type        289230 non-null  object
#  3   registration_year   310430 non-null  int64
#  4   gearbox             300907 non-null  object
#  5   power               310430 non-null  int64
#  6   model               298168 non-null  object
#  7   mileage             310430 non-null  int64
#  8   registration_month  310430 non-null  int64
#  9   fuel_type           292326 non-null  object
#  10  brand               310430 non-null  object
#  11  not_repaired        263706 non-null  object
#  12  date_created        310430 non-null  datetime64[ns]
#  13  number_of_pictures  310430 non-null  int64
#  14  postal_code         310430 non-null  int64
#  15  last_seen           310430 non-null  datetime64[ns]
# dtypes: datetime64[ns](3), int64(7), object(6)
# memory usage: 37.9+ MB

# %% [markdown]
# Ahora se imprimirán los valores únicos de las columnas con datos categóricos. La primera columna es `vhicle_type`.

# %%
categorical = ['vehicle_type', 'gearbox', 'model', 'fuel_type', 'brand', 'not_repaired']

for item in categorical:
    print(item)
    print(data[item].sort_values().unique())
    print()
# Out:
# vehicle_type
# ['bus' 'convertible' 'coupe' 'other' 'sedan' 'small' 'suv' 'wagon' nan]
#
# gearbox
# ['auto' 'manual' nan]
#
# model
# ['100' '145' '147' '156' '159' '1_reihe' '1er' '200' '2_reihe' '300c'
#  '3_reihe' '3er' '4_reihe' '500' '5_reihe' '5er' '601' '6_reihe' '6er'
#  '7er' '80' '850' '90' '900' '9000' '911' 'a1' 'a2' 'a3' 'a4' 'a5' 'a6'
#  'a8' 'a_klasse' 'accord' 'agila' 'alhambra' 'almera' 'altea' 'amarok'
#  'antara' 'arosa' 'astra' 'auris' 'avensis' 'aveo' 'aygo' 'b_klasse'
#  'b_max' 'beetle' 'berlingo' 'bora' 'boxster' 'bravo' 'c1' 'c2' 'c3' 'c4'
#  'c5' 'c_klasse' 'c_max' 'c_reihe' 'caddy' 'calibra' 'captiva' 'carisma'
#  'carnival' 'cayenne' 'cc' 'ceed' 'charade' 'cherokee' 'citigo' 'civic'
#  'cl' 'clio' 'clk' 'clubman' 'colt' 'combo' 'cooper' 'cordoba' 'corolla'
#  'corsa' 'cr_reihe' 'croma' 'crossfire' 'cuore' 'cx_reihe' 'defender'
#  'delta' 'discovery' 'doblo' 'ducato' 'duster' 'e_klasse' 'elefantino'
#  'eos' 'escort' 'espace' 'exeo' 'fabia' 'fiesta' 'focus' 'forester'
#  'forfour' 'fortwo' 'fox' 'freelander' 'fusion' 'g_klasse' 'galant'
#  'galaxy' 'getz' 'gl' 'glk' 'golf' 'grand' 'i3' 'i_reihe' 'ibiza'
#  'impreza' 'insignia' 'jazz' 'jetta' 'jimny' 'juke' 'justy' 'ka' 'kadett'
#  'kaefer' 'kalina' 'kalos' 'kangoo' 'kappa' 'kuga' 'laguna' 'lancer'
#  'lanos' 'legacy' 'leon' 'lodgy' 'logan' 'lupo' 'lybra' 'm_klasse'
#  'm_reihe' 'materia' 'matiz' 'megane' 'meriva' 'micra' 'mii' 'modus'
#  'mondeo' 'move' 'musa' 'mustang' 'mx_reihe' 'navara' 'niva' 'note'
#  'nubira' 'octavia' 'omega' 'one' 'other' 'outlander' 'pajero' 'panda'
#  'passat' 'phaeton' 'picanto' 'polo' 'primera' 'ptcruiser' 'punto' 'q3'
#  'q5' 'q7' 'qashqai' 'r19' 'range_rover' 'range_rover_evoque'
#  'range_rover_sport' 'rangerover' 'rav' 'rio' 'roadster' 'roomster'
#  'rx_reihe' 's60' 's_klasse' 's_max' 's_type' 'samara' 'sandero' 'santa'
#  'scenic' 'scirocco' 'seicento' 'serie_2' 'serie_3' 'sharan' 'signum'
#  'sirion' 'sl' 'slk' 'sorento' 'spark' 'spider' 'sportage' 'sprinter'
#  'stilo' 'superb' 'swift' 'terios' 'tigra' 'tiguan' 'toledo' 'touareg'
#  'touran' 'transit' 'transporter' 'tt' 'tucson' 'twingo' 'up' 'v40' 'v50'
#  'v60' 'v70' 'v_klasse' 'vectra' 'verso' 'viano' 'vito' 'vivaro' 'voyager'
#  'wrangler' 'x_reihe' 'x_trail' 'x_type' 'xc_reihe' 'yaris' 'yeti'
#  'ypsilon' 'z_reihe' 'zafira' nan]
#
# fuel_type
# ['cng' 'electric' 'gasoline' 'hybrid' 'lpg' 'other' 'petrol' nan]
#
# brand
# ['alfa_romeo' 'audi' 'bmw' 'chevrolet' 'chrysler' 'citroen' 'dacia'
#  'daewoo' 'daihatsu' 'fiat' 'ford' 'honda' 'hyundai' 'jaguar' 'jeep' 'kia'
#  'lada' 'lancia' 'land_rover' 'mazda' 'mercedes_benz' 'mini' 'mitsubishi'
#  'nissan' 'opel' 'peugeot' 'porsche' 'renault' 'rover' 'saab' 'seat'
#  'skoda' 'smart' 'sonstige_autos' 'subaru' 'suzuki' 'toyota' 'trabant'
#  'volkswagen' 'volvo']
#
# not_repaired
# ['no' 'yes' nan]

# %% [markdown]
# No existen duplicados implícitos en ninguna de las columnas categóricas. En la siguiente sección se tratarán los valores ausentes.
#
# [Volver a Contenidos](#back)

# %% [markdown]
# ### 1. 3. Valores ausentes <a id='data_review_missing'></a>
#
# Se imprimirá la información sobre los valores ausentes.

# %%
print(data.isna().sum())
# Out:
# date_crawled              0
# price                     0
# vehicle_type          21200
# registration_year         0
# gearbox                9523
# power                     0
# model                 12262
# mileage                   0
# registration_month        0
# fuel_type             18104
# brand                     0
# not_repaired          46724
# date_created              0
# number_of_pictures        0
# postal_code               0
# last_seen                 0
# dtype: int64

# %% [markdown]
# La columna `not_repaired` es la que contiene una mayor cantidad de valores ausentes y no es posible determinar esta información a partir de las otras columnas, por lo que se rellenarán estos valores con `'unknown'`.

# %%
data['not_repaired'] = data['not_repaired'].fillna('unknown')
print(data.isna().sum())
# Out:
# date_crawled              0
# price                     0
# vehicle_type          21200
# registration_year         0
# gearbox                9523
# power                     0
# model                 12262
# mileage                   0
# registration_month        0
# fuel_type             18104
# brand                     0
# not_repaired              0
# date_created              0
# number_of_pictures        0
# postal_code               0
# last_seen                 0
# dtype: int64

# %% [markdown]
# Ahora la columna con mayor cantidad de valores ausentes es `vehicle_type`, estas filas representan casi el 7% del tamaño del dataframe. Las otras columnas son `gearbox`, `model` y `fuel_type`, las cuales no se pueden determinar con las datos que se tienen. Por esta razón, se decide elimnar las filas que contienen valores ausentes.

# %%
data = data.dropna().reset_index(drop=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265967 entries, 0 to 265966
# Data columns (total 16 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   date_crawled        265967 non-null  datetime64[ns]
#  1   price               265967 non-null  int64
#  2   vehicle_type        265967 non-null  object
#  3   registration_year   265967 non-null  int64
#  4   gearbox             265967 non-null  object
#  5   power               265967 non-null  int64
#  6   model               265967 non-null  object
#  7   mileage             265967 non-null  int64
#  8   registration_month  265967 non-null  int64
#  9   fuel_type           265967 non-null  object
#  10  brand               265967 non-null  object
#  11  not_repaired        265967 non-null  object
#  12  date_created        265967 non-null  datetime64[ns]
#  13  number_of_pictures  265967 non-null  int64
#  14  postal_code         265967 non-null  int64
#  15  last_seen           265967 non-null  datetime64[ns]
# dtypes: datetime64[ns](3), int64(7), object(6)
# memory usage: 32.5+ MB

# %% [markdown]
# No existen valores ausentes.
#
# [Volver a Contenidos](#back)

# %% [markdown]
# ### 1. 4. Conclusiones <a id='data_review_conclusions'></a>
#
# En esta etapa se abrió el archivo y se guardó en un dataset, el cual contiene información del automóvil como precio, tipo, año y mes de registro, tipo de transmisión, potencia, modelo, kilometraje, tipo de combustible, marca y si ha sido reparado o no. También contiene información del usuario como las fechas en las que se creo el perfil, última vez de actividad o en la que se descargaron los datos.
#
# Se cambió el formato de los nombres de las columnas a la manera convencional (minúsculas y con space case). Se cambió el formato de las columnas con fechas, se eliminaron filas duplicadas y se trataron los valores ausentes. Los valores ausentes de la columna con la información de posibles reparaciones se reemplazaron con `'unknown'` y se eliminaron todos las filas con valores ausentes en las columnas restantes.
#
# En la siguiente etapa se entrenarán modelos y se buscará el de mejor calidad.
#
# [Volver a Contenidos](#back)

# %% [markdown]
# ## Etapa 2. Entrenamiento del modelo <a id='data_model'></a>
#
# En esta etapa se entrenarán modelos con 5 diferentes algoritmos: regresión lineal, árbol de decisión, bosque aleatorio, CatBoost y LightGBM.
#
# La columna objetivo del modelo es la columna `price` y las columnas que no aportan información para entrenar a los modelos son:
# - `date_crawled` - información de usuario no del auto.
# - `date_created` - información de usuario no del auto.
# - `number_of_pictures` - sin utilidad.
# - `postal_code` _ información de usuario no del auto.
# - `last_seen` - información de usuario no del auto.
#
# Así, las características son las columnas restantes.

# %%
features = data.drop(['price', 'date_crawled', 'date_created', 'number_of_pictures', 'postal_code', 'last_seen'], axis=1)
target = data['price']

features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265967 entries, 0 to 265966
# Data columns (total 10 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   vehicle_type        265967 non-null  object
#  1   registration_year   265967 non-null  int64
#  2   gearbox             265967 non-null  object
#  3   power               265967 non-null  int64
#  4   model               265967 non-null  object
#  5   mileage             265967 non-null  int64
#  6   registration_month  265967 non-null  int64
#  7   fuel_type           265967 non-null  object
#  8   brand               265967 non-null  object
#  9   not_repaired        265967 non-null  object
# dtypes: int64(4), object(6)
# memory usage: 20.3+ MB

# %% [markdown]
# Para los modelos basados en regresión lineal, árbol de decisión y bosque aleatorio, es necesario codificar las variables categóricas.

# %%
categorical = ['vehicle_type', 'gearbox', 'model', 'registration_month','fuel_type', 'brand', 'not_repaired']

ohe = pd.get_dummies(data = features, columns = categorical, drop_first=True)

# %% [markdown]
# De esta manera, se pueden dividir los datos en conjunto de entrenamiento y de prueba, con una proporción de 4:1. Como los otros modelos no necesitan la codificación de las variables categóricas, entonces también se dividirá sin la codificación.

# %%
features_train_ohe, features_test_ohe, target_train_ohe, target_test_ohe = train_test_split(ohe, target, test_size=0.2, random_state=54321)
features_train, features_test, target_train, target_test = train_test_split(features, target, test_size=0.2, random_state=54321)

print('Tamaño de features_train_ohe:', features_train_ohe.shape)
print('Tamaño de features_test_ohe:', features_test_ohe.shape)
print('Tamaño de target_train_ohe:', target_train_ohe.shape)
print('Tamaño de target_test_ohe:', target_test_ohe.shape)
print()
print('Tamaño de features_train:', features_train.shape)
print('Tamaño de features_test:', features_test.shape)
print('Tamaño de target_train:', target_train.shape)
print('Tamaño de target_test:', target_test.shape)
# Out:
# Tamaño de features_train_ohe: (212773, 316)
# Tamaño de features_test_ohe: (53194, 316)
# Tamaño de target_train_ohe: (212773,)
# Tamaño de target_test_ohe: (53194,)
#
# Tamaño de features_train: (212773, 10)
# Tamaño de features_test: (53194, 10)
# Tamaño de target_train: (212773,)
# Tamaño de target_test: (53194,)

# %% [markdown]
# También se estandarizarán las variables numéricas.

# %%
numerics = ['registration_year', 'power', 'mileage']

scaler = StandardScaler()
scaler.fit(features_train_ohe[numerics])

features_train[numerics] = scaler.transform(features_train[numerics])
features_test[numerics] = scaler.transform(features_test[numerics])

features_train_ohe[numerics] = scaler.transform(features_train_ohe[numerics])
features_test_ohe[numerics] = scaler.transform(features_test_ohe[numerics])

# %% [markdown]
# Se utilizará la métrica RECM para evaluar la calidad de los modelos, por ello se creará la función, utilizando la función `mean_squared_error`.

# %%
def rmse(y_true, y_predict):
    mse = mean_squared_error(y_true, y_predict)
    return mse ** 0.5

rmse_scorer = make_scorer(rmse, greater_is_better=False)

# %% [markdown]
# Finalmente, se creará una tabla para registrar la información resultante de entrenar los modelos y así poder compararlos.

# %%
model_info = pd.DataFrame(columns=('model','fit_time','predict_time','rmse'))
model_info.head()
# Out:
# Empty DataFrame
# Columns: [model, fit_time, predict_time, rmse]
# Index: []

# %% [markdown]
# Ya se tiene lo necesario para comenzar el entrenamiento de los modelos.
#
# [Volver a Contenidos](#back)

# %% [markdown]
# ### 2. 1. Regresión lineal <a id='data_model_linear'></a>
#
# El primer modelo a entrenar será basado en la regresión lineal. Este modelo se utilizará como la métrica RECM a superar.
#
# Se realizará validación cruzada.

# %%
lr_model = LinearRegression()
lr_score=cross_val_score(lr_model, features_train_ohe, target_train_ohe, scoring=rmse_scorer, cv=5)
print(lr_score.mean())
# Out:
# -2674.935711842474

# %% [markdown]
# Se entrenará al modelo y se tomará el tiempo, así como el tiempo de predicción y se calculará el RECM para adjuntar los datos en la tabla.

# %%
#fila con la información del modelo
lr_info = ['Linear Regression']

#Tomar tiempo de entrenamiento
start = time.time()
lr_model.fit(features_train_ohe, target_train_ohe)
end=time.time()

#agregar el tiempo de entrenamiento
lr_info.append(end - start)

#Tomar tiempo de predicción
start = time.time()
lr_predict = lr_model.predict(features_test_ohe)
end=time.time()

#agregar el tiempo de predicción
lr_info.append(end - start)

#RMSE
lr_rmse = rmse(target_test_ohe, lr_predict)

#add to row
lr_info.append(lr_rmse)

model_info.loc[len(model_info)] = lr_info
model_info.head()
# Out:
#                model  fit_time  predict_time         rmse
# 0  Linear Regression  2.791132      0.027558  2688.063915

# %% [markdown]
# Se analizará si con otros modelos se puede obtener un RECM menor.
#
# [Volver a Contenidos](#back)

# %% [markdown]
# ### 2. 2. Árbol de decisión <a id='data_model_tree'></a>
#
# A continuación se utilizará el algoritmo de árbol de decisión y se entrenarán modelos variando la profundidad y evaluando con validación cruzada.

# %%
for depth in range(1, 21):
    dt_model = DecisionTreeRegressor(max_depth=depth, random_state=54321)
    dt_score = cross_val_score(dt_model, features_train_ohe, target_train_ohe, scoring=rmse_scorer, cv=5)
    print('Max_depth', depth, 'score:', dt_score.mean())
# Out:
# Max_depth 1 score: -3577.4451257216883
# Max_depth 2 score: -3135.405101217395
# Max_depth 3 score: -2789.976861087192
# Max_depth 4 score: -2546.9779781927123
# Max_depth 5 score: -2387.775782323587
# Max_depth 6 score: -2273.2288046255053
# Max_depth 7 score: -2177.0671578053516
# Max_depth 8 score: -2096.859174723884
# Max_depth 9 score: -2033.9497795458458
# Max_depth 10 score: -1981.8721848843575
# Max_depth 11 score: -1942.935063562259
# Max_depth 12 score: -1908.8567839310635
# Max_depth 13 score: -1883.7408241896642
# Max_depth 14 score: -1869.1147979669108
# Max_depth 15 score: -1860.476417129131
# Max_depth 16 score: -1859.4763123377295
# Max_depth 17 score: -1859.0264029100624
# Max_depth 18 score: -1866.0778038267467
# Max_depth 19 score: -1873.20719374104
# Max_depth 20 score: -1879.6643962929277

# %% [markdown]
# El mejor modelo es con profundidad máximas igual a 17, de esta manera se medirá el tiempo de entrenamiento y predicción con esta profundidad.

# %%
#fila con la información del modelo
dt_info = ['Decision Tree']

dt_model = DecisionTreeRegressor(max_depth=17, random_state=54321)

#Tomar tiempo de entrenamiento
start = time.time()
dt_model.fit(features_train_ohe, target_train_ohe)
end=time.time()

#agregar el tiempo de entrenamiento
dt_info.append(end - start)

#Tomar tiempo de predicción
start = time.time()
dt_predict = dt_model.predict(features_test_ohe)
end=time.time()

#agregar el tiempo de predicción
dt_info.append(end - start)

#RMSE
dt_rmse = rmse(target_test_ohe, dt_predict)

#add to row
dt_info.append(dt_rmse)

model_info.loc[len(model_info)] = dt_info
model_info.head()
# Out:
#                model  fit_time  predict_time         rmse
# 0  Linear Regression  2.791132      0.027558  2688.063915
# 1      Decision Tree  2.387368      0.031758  1834.772587

# %% [markdown]
# Este modelo ha mejorado tanto los tiempos como la métrica RECM del modelo basado en la regresión lineal.
#
# [Volver a Contenidos](#back)

# %% [markdown]
# ### 2. 3. Bosque aleatorio <a id='data_model_forest'></a>
#
# A continuación se utilizará el algoritmo de bosque aleatorio y se entrenarán modelos variando la profundidad y evaluando con validación cruzada. Se considerarán 50 árboles.

# %%
#Previamente se utilizó un rango de 1 a 26 pero el proceso tardaba más de 2 horas
for depth in range(24, 26):
    rf = RandomForestRegressor(n_estimators=50, max_depth=depth, random_state=54321)
    rf_score = cross_val_score(rf, features_train_ohe, target_train_ohe, scoring=rmse_scorer, cv=5)
    print('Max_depth', depth, 'score:', rf_score.mean())
# Out:
# Max_depth 24 score: -1571.4557267767864
# Max_depth 25 score: -1570.8727012449758

# %% [markdown]
# El mejor modelo es con profundidad igual a 25 aunque es muy probable que se obtenga un mejor puntaje a mayor profundidad, sin embargo, el tiempo de entrenamiento es cada vez más lento. Por ello se tomará este parámetro.

# %%
#fila con la información del modelo
rf_info = ['Random Forest']

rf_model = RandomForestRegressor(n_estimators=50, max_depth=25, random_state=54321)

#Tomar tiempo de entrenamiento
start = time.time()
rf_model.fit(features_train_ohe, target_train_ohe)
end=time.time()

#agregar el tiempo de entrenamiento
rf_info.append(end - start)

#Tomar tiempo de predicción
start = time.time()
rf_predict = rf_model.predict(features_test_ohe)
end=time.time()

#agregar el tiempo de predicción
rf_info.append(end - start)

#RMSE
rf_rmse = rmse(target_test_ohe, rf_predict)

#add to row
rf_info.append(rf_rmse)

model_info.loc[len(model_info)] = rf_info
model_info.head()
# Out:
#                model   fit_time  predict_time         rmse
# 0  Linear Regression   2.791132      0.027558  2688.063915
# 1      Decision Tree   2.387368      0.031758  1834.772587
# 2      Random Forest  85.885852      0.521819  1560.465073

# %% [markdown]
# Este modelo tiene el menor RECM pero es el que ha registrado mayor tiempo tanto de entrenamiendo como de predicción.
#
# [Volver a Contenidos](#back)

# %% [markdown]
# ### 2. 4. CatBoost <a id='data_model_catboost'></a>
#
# Se utilizará CatBoostRegressor para entrenar al modelo. Este algoritmo no necesita la codificación de las variables categóricas. Se utilizarán diferentes hiperparámetros y se encontrarán los mejores utilizando GridSearchCV.

# %%
cbr_model = CatBoostRegressor()

#diccionario de parámetros
parameters = {
    'depth' : [12, 14, 16],
    'learning_rate' : [0.05, 0.1],
    'iterations' : [50, 100]
}

#bucles para encontrar los mejores hiperparámetros
grid = GridSearchCV(estimator=cbr_model, param_grid=parameters, scoring=rmse_scorer, cv=3, n_jobs=-1, verbose=0)

#entrenamiento sin codificación
grid.fit(features_train, target_train, cat_features=categorical)

#Mejores parámetros
print('Resultados de GridSearch')
print("\n La mejor puntuación:", grid.best_score_)
print("\n Los mejores parámetros:\n", grid.best_params_)

best_param=grid.best_params_
# Out:
# 0:	learn: 4485.5645162	total: 156ms	remaining: 7.65s
# 0:	learn: 4497.4043066	total: 208ms	remaining: 10.2s
# 1:	learn: 4322.9887987	total: 291ms	remaining: 6.97s
# 0:	learn: 4314.2564331	total: 232ms	remaining: 11.4s
# 1:	learn: 4336.0033555	total: 331ms	remaining: 7.93s
# 0:	learn: 4320.0193883	total: 243ms	remaining: 11.9s
# 0:	learn: 4489.9098061	total: 275ms	remaining: 13.5s
# 2:	learn: 4170.5384597	total: 443ms	remaining: 6.95s
# 0:	learn: 4327.2260118	total: 171ms	remaining: 8.39s
# 1:	learn: 4012.1549845	total: 385ms	remaining: 9.23s
# 2:	learn: 4184.9662865	total: 488ms	remaining: 7.64s
# 0:	learn: 4485.5645162	total: 255ms	remaining: 25.2s
# 1:	learn: 4019.4832554	total: 445ms	remaining: 10.7s
# 1:	learn: 4327.7120209	total: 496ms	remaining: 11.9s
# 0:	learn: 4489.9098061	total: 282ms	remaining: 28s
# 1:	learn: 4027.8279876	total: 326ms	remaining: 7.83s
# 3:	learn: 4027.0300044	total: 627ms	remaining: 7.21s
# 2:	learn: 3746.6241966	total: 571ms	remaining: 8.95s
# 3:	learn: 4040.7480353	total: 682ms	remaining: 7.84s
# 1:	learn: 4322.9887987	total: 421ms	remaining: 20.6s
# 2:	learn: 3749.8643565	total: 623ms	remaining: 9.76s
# 4:	learn: 3892.3446102	total: 780ms	remaining: 7.02s
# 2:	learn: 4176.6293986	total: 693ms	remaining: 10.9s
# 2:	learn: 3763.5680491	total: 536ms	remaining: 8.4s
# 1:	learn: 4327.7120209	total: 496ms	remaining: 24.3s
# 3:	learn: 3508.5363177	total: 744ms	remaining: 8.55s
# 4:	learn: 3905.9541296	total: 832ms	remaining: 7.49s
# 3:	learn: 3511.6076526	total: 758ms	remaining: 8.72s
# 5:	learn: 3767.3834292	total: 887ms	remaining: 6.5s
# 2:	learn: 4170.5384597	total: 624ms	remaining: 20.2s
# 3:	learn: 4035.7263436	total: 854ms	remaining: 9.82s
# 2:	learn: 4176.6293986	total: 638ms	remaining: 20.6s
# 5:	learn: 3780.2548825	total: 946ms	remaining: 6.94s
# 3:	learn: 3524.8559525	total: 708ms	remaining: 8.14s
# 4:	learn: 3304.9459737	total: 942ms	remaining: 8.48s
# 6:	learn: 3648.4714125	total: 1.05s	remaining: 6.46s
# 4:	learn: 3303.1534928	total: 934ms	remaining: 8.4s
# 3:	learn: 4035.7263436	total: 770ms	remaining: 18.5s
# 3:	learn: 4027.0300044	total: 789ms	remaining: 18.9s
# 4:	learn: 3317.1311555	total: 822ms	remaining: 7.4s
# 4:	learn: 3900.3341460	total: 1.03s	remaining: 9.25s
# 6:	learn: 3660.1846753	total: 1.13s	remaining: 6.96s
# 7:	learn: 3535.6482559	total: 1.22s	remaining: 6.4s
# 5:	learn: 3136.4442243	total: 950ms	remaining: 6.97s
# 5:	learn: 3771.7743293	total: 1.16s	remaining: 8.49s
# 5:	learn: 3123.8053889	total: 1.19s	remaining: 8.7s
# 5:	learn: 3118.9979909	total: 1.15s	remaining: 8.43s
# 4:	learn: 3900.3341460	total: 947ms	remaining: 18s
# 4:	learn: 3892.3446102	total: 974ms	remaining: 18.5s
# 7:	learn: 3548.7647149	total: 1.33s	remaining: 6.97s
# 8:	learn: 3429.1927593	total: 1.37s	remaining: 6.24s
# 6:	learn: 2979.8847258	total: 1.09s	remaining: 6.7s
# 6:	learn: 3650.0039473	total: 1.31s	remaining: 8.06s
# 6:	learn: 2969.7529153	total: 1.34s	remaining: 8.21s
# 6:	learn: 2962.2728737	total: 1.31s	remaining: 8.05s
# 5:	learn: 3771.7743293	total: 1.11s	remaining: 17.4s
# 5:	learn: 3767.3834292	total: 1.14s	remaining: 17.9s
# 8:	learn: 3442.1083603	total: 1.45s	remaining: 6.62s
# 7:	learn: 2836.8989130	total: 1.22s	remaining: 6.43s
# 9:	learn: 3330.4960773	total: 1.54s	remaining: 6.16s
# 7:	learn: 3535.1075770	total: 1.48s	remaining: 7.75s
# 7:	learn: 2830.4901940	total: 1.5s	remaining: 7.9s
# 7:	learn: 2822.7628246	total: 1.49s	remaining: 7.82s
# 6:	learn: 3648.4714125	total: 1.32s	remaining: 17.6s
# 9:	learn: 3341.3053062	total: 1.62s	remaining: 6.47s
# 6:	learn: 3650.0039473	total: 1.33s	remaining: 17.7s
# 8:	learn: 2706.9625808	total: 1.61s	remaining: 7.36s
# 8:	learn: 2712.3094641	total: 1.44s	remaining: 6.54s
# 10:	learn: 3237.3226761	total: 1.72s	remaining: 6.09s
# 8:	learn: 3428.1395456	total: 1.66s	remaining: 7.57s
# 7:	learn: 3535.6482559	total: 1.5s	remaining: 17.2s
# 7:	learn: 3535.1075770	total: 1.49s	remaining: 17.2s
# 10:	learn: 3248.3008829	total: 1.79s	remaining: 6.35s
# 8:	learn: 2701.8847920	total: 1.7s	remaining: 7.76s
# 11:	learn: 3149.6848775	total: 1.85s	remaining: 5.87s
# 9:	learn: 2608.9192705	total: 1.59s	remaining: 6.36s
# 9:	learn: 2598.2551088	total: 1.83s	remaining: 7.34s
# 9:	learn: 3328.4663339	total: 1.82s	remaining: 7.27s
# 8:	learn: 3429.1927593	total: 1.64s	remaining: 16.5s
# 11:	learn: 3160.7663739	total: 1.93s	remaining: 6.12s
# 9:	learn: 2596.5673463	total: 1.84s	remaining: 7.35s
# 8:	learn: 3428.1395456	total: 1.7s	remaining: 17.2s
# 10:	learn: 2501.3972430	total: 1.75s	remaining: 6.19s
# 10:	learn: 3240.8842842	total: 1.94s	remaining: 6.86s
# 12:	learn: 3067.7881754	total: 2.03s	remaining: 5.77s
# 12:	learn: 3080.3527643	total: 2.06s	remaining: 5.86s
# 9:	learn: 3330.4960773	total: 1.79s	remaining: 16.1s
# 10:	learn: 2507.0227598	total: 1.99s	remaining: 7.07s
# 10:	learn: 2504.7944939	total: 2.04s	remaining: 7.22s
# 11:	learn: 2407.9522491	total: 1.88s	remaining: 5.94s
# 9:	learn: 3328.4663339	total: 1.86s	remaining: 16.8s
# 11:	learn: 3151.8508243	total: 2.09s	remaining: 6.63s
# 13:	learn: 3004.1141163	total: 2.19s	remaining: 5.62s
# 11:	learn: 2408.5789533	total: 2.16s	remaining: 6.83s
# 10:	learn: 3237.3226761	total: 1.94s	remaining: 15.7s
# 11:	learn: 2409.3228391	total: 2.13s	remaining: 6.75s
# 13:	learn: 2990.9451434	total: 2.25s	remaining: 5.78s
# 10:	learn: 3240.8842842	total: 1.97s	remaining: 15.9s
# 12:	learn: 2323.1402293	total: 2.03s	remaining: 5.79s
# 14:	learn: 2932.9222241	total: 2.31s	remaining: 5.39s
# 12:	learn: 2321.4020169	total: 2.28s	remaining: 6.5s
# 11:	learn: 3149.6848775	total: 2.07s	remaining: 15.2s
# 12:	learn: 3071.5468192	total: 2.29s	remaining: 6.53s
# 12:	learn: 2326.2778546	total: 2.29s	remaining: 6.52s
# 11:	learn: 3151.8508243	total: 2.1s	remaining: 15.4s
# 14:	learn: 2919.2476306	total: 2.4s	remaining: 5.61s
# 13:	learn: 2246.9366626	total: 2.37s	remaining: 6.11s
# 13:	learn: 2254.2382096	total: 2.2s	remaining: 5.65s
# 12:	learn: 3067.7881754	total: 2.18s	remaining: 14.6s
# 15:	learn: 2864.4624173	total: 2.52s	remaining: 5.35s
# 14:	learn: 2185.2251157	total: 2.47s	remaining: 5.77s
# 13:	learn: 2255.2315719	total: 2.44s	remaining: 6.27s
# 12:	learn: 3071.5468192	total: 2.25s	remaining: 15s
# 13:	learn: 2993.6876799	total: 2.47s	remaining: 6.35s
# 14:	learn: 2191.1957312	total: 2.33s	remaining: 5.42s
# 15:	learn: 2851.0986445	total: 2.61s	remaining: 5.55s
# 13:	learn: 2990.9451434	total: 2.34s	remaining: 14.4s
# 15:	learn: 2131.9018233	total: 2.58s	remaining: 5.49s
# 14:	learn: 2921.6345344	total: 2.59s	remaining: 6.04s
# 14:	learn: 2193.8369627	total: 2.57s	remaining: 6s
# 13:	learn: 2993.6876799	total: 2.38s	remaining: 14.6s
# 16:	learn: 2802.6711868	total: 2.68s	remaining: 5.2s
# 16:	learn: 2786.3671416	total: 2.75s	remaining: 5.34s
# 14:	learn: 2919.2476306	total: 2.47s	remaining: 14s
# 15:	learn: 2137.7465348	total: 2.5s	remaining: 5.32s
# 16:	learn: 2086.9726661	total: 2.73s	remaining: 5.29s
# 17:	learn: 2741.9293309	total: 2.78s	remaining: 4.94s
# 15:	learn: 2141.5115144	total: 2.71s	remaining: 5.76s
# 14:	learn: 2921.6345344	total: 2.54s	remaining: 14.4s
# 15:	learn: 2854.9361313	total: 2.77s	remaining: 5.89s
# 15:	learn: 2851.0986445	total: 2.59s	remaining: 13.6s
# 16:	learn: 2085.1987664	total: 2.64s	remaining: 5.12s
# 17:	learn: 2727.5086269	total: 2.91s	remaining: 5.18s
# 18:	learn: 2676.3741282	total: 2.92s	remaining: 4.76s
# 17:	learn: 2039.7501385	total: 2.88s	remaining: 5.12s
# 16:	learn: 2093.9813160	total: 2.84s	remaining: 5.52s
# 15:	learn: 2854.9361313	total: 2.66s	remaining: 14s
# 16:	learn: 2791.6804637	total: 2.91s	remaining: 5.65s
# 16:	learn: 2786.3671416	total: 2.71s	remaining: 13.3s
# 18:	learn: 2672.6122478	total: 3.04s	remaining: 4.96s
# 18:	learn: 1997.5429341	total: 3s	remaining: 4.9s
# 17:	learn: 2038.2763727	total: 2.81s	remaining: 4.99s
# 17:	learn: 2045.0772988	total: 2.98s	remaining: 5.29s
# 16:	learn: 2791.6804637	total: 2.78s	remaining: 13.6s
# 19:	learn: 2616.4189306	total: 3.09s	remaining: 4.64s
# 17:	learn: 2732.0329691	total: 3.06s	remaining: 5.43s
# 17:	learn: 2727.5086269	total: 2.86s	remaining: 13s
# 17:	learn: 2732.0329691	total: 2.88s	remaining: 13.1s
# 19:	learn: 2621.6405936	total: 3.2s	remaining: 4.79s
# 18:	learn: 1998.2882146	total: 2.93s	remaining: 4.78s
# 18:	learn: 2002.7761010	total: 3.1s	remaining: 5.05s
# 19:	learn: 1961.5625570	total: 3.18s	remaining: 4.76s
# 18:	learn: 2672.6122478	total: 2.98s	remaining: 12.7s
# 20:	learn: 2560.1127308	total: 3.27s	remaining: 4.51s
# 18:	learn: 2676.2965258	total: 3.2s	remaining: 5.22s
# 19:	learn: 1963.1308296	total: 3.06s	remaining: 4.59s
# 19:	learn: 1966.1371450	total: 3.23s	remaining: 4.85s
# 20:	learn: 2564.2620595	total: 3.35s	remaining: 4.62s
# 18:	learn: 2676.2965258	total: 3.06s	remaining: 13s
# 20:	learn: 1929.4166439	total: 3.3s	remaining: 4.56s
# 21:	learn: 2507.9625973	total: 3.39s	remaining: 4.32s
# 19:	learn: 2621.6405936	total: 3.13s	remaining: 12.5s
# 19:	learn: 2624.6214108	total: 3.35s	remaining: 5.02s
# 20:	learn: 1933.1348023	total: 3.19s	remaining: 4.41s
# 21:	learn: 2509.8187307	total: 3.48s	remaining: 4.43s
# 21:	learn: 1901.2488418	total: 3.42s	remaining: 4.36s
# 20:	learn: 1935.5092810	total: 3.38s	remaining: 4.67s
# 22:	learn: 2459.5860096	total: 3.53s	remaining: 4.14s
# 19:	learn: 2624.6214108	total: 3.24s	remaining: 13s
# 20:	learn: 2564.2620595	total: 3.28s	remaining: 12.3s
# 21:	learn: 1908.5480746	total: 3.48s	remaining: 4.43s
# 21:	learn: 1908.4517716	total: 3.32s	remaining: 4.22s
# 20:	learn: 2575.0628794	total: 3.53s	remaining: 4.87s
# 22:	learn: 2460.0814208	total: 3.62s	remaining: 4.24s
# 22:	learn: 1877.9189060	total: 3.58s	remaining: 4.2s
# 23:	learn: 2413.8956608	total: 3.64s	remaining: 3.94s
# 20:	learn: 2575.0628794	total: 3.38s	remaining: 12.7s
# 21:	learn: 2509.8187307	total: 3.41s	remaining: 12.1s
# 22:	learn: 1883.8838396	total: 3.62s	remaining: 4.25s
# 23:	learn: 2413.9846336	total: 3.75s	remaining: 4.06s
# 22:	learn: 1886.3141939	total: 3.47s	remaining: 4.07s
# 23:	learn: 1857.6329464	total: 3.7s	remaining: 4s
# 21:	learn: 2521.3622492	total: 3.7s	remaining: 4.71s
# 24:	learn: 2372.6966687	total: 3.79s	remaining: 3.79s
# 21:	learn: 2521.3622492	total: 3.51s	remaining: 12.4s
# 23:	learn: 1864.9820700	total: 3.59s	remaining: 3.89s
# 22:	learn: 2460.0814208	total: 3.58s	remaining: 12s
# 24:	learn: 1838.2239328	total: 3.82s	remaining: 3.82s
# 22:	learn: 2471.9523629	total: 3.81s	remaining: 4.48s
# 24:	learn: 2371.4589374	total: 3.91s	remaining: 3.91s
# 23:	learn: 1863.5110763	total: 3.8s	remaining: 4.12s
# 22:	learn: 2471.9523629	total: 3.64s	remaining: 12.2s
# 25:	learn: 2333.7196665	total: 3.95s	remaining: 3.65s
# 23:	learn: 2427.1027732	total: 3.92s	remaining: 4.25s
# 24:	learn: 1846.9420890	total: 3.73s	remaining: 3.73s
# 25:	learn: 1820.7730298	total: 3.97s	remaining: 3.66s
# 25:	learn: 2330.4746280	total: 4.04s	remaining: 3.73s
# 24:	learn: 1845.3317305	total: 3.94s	remaining: 3.94s
# 23:	learn: 2413.9846336	total: 3.77s	remaining: 11.9s
# 23:	learn: 2427.1027732	total: 3.77s	remaining: 11.9s
# 26:	learn: 2296.7676182	total: 4.07s	remaining: 3.47s
# 24:	learn: 2384.6299658	total: 4.04s	remaining: 4.04s
# 25:	learn: 1829.7200366	total: 3.87s	remaining: 3.57s
# 26:	learn: 1806.3155759	total: 4.09s	remaining: 3.48s
# 25:	learn: 1829.4609166	total: 4.06s	remaining: 3.75s
# 26:	learn: 2294.4453710	total: 4.2s	remaining: 3.58s
# 24:	learn: 2371.4589374	total: 3.91s	remaining: 11.7s
# 27:	learn: 2262.1527699	total: 4.2s	remaining: 3.3s
# 24:	learn: 2384.6299658	total: 3.92s	remaining: 11.8s
# 26:	learn: 1816.9594523	total: 3.97s	remaining: 3.38s
# 25:	learn: 2344.9207747	total: 4.17s	remaining: 3.85s
# 27:	learn: 1793.3189135	total: 4.21s	remaining: 3.31s
# 26:	learn: 1815.3889914	total: 4.18s	remaining: 3.56s
# 27:	learn: 2260.1113654	total: 4.3s	remaining: 3.38s
# 28:	learn: 2230.3292819	total: 4.31s	remaining: 3.12s
# 25:	learn: 2330.4746280	total: 4.03s	remaining: 11.5s
# 25:	learn: 2344.9207747	total: 4.04s	remaining: 11.5s
# 27:	learn: 1803.4459113	total: 4.12s	remaining: 3.24s
# 28:	learn: 1780.7007682	total: 4.35s	remaining: 3.15s
# 26:	learn: 2306.4179624	total: 4.33s	remaining: 3.69s
# 27:	learn: 1802.9221150	total: 4.32s	remaining: 3.39s
# 28:	learn: 2228.1498150	total: 4.43s	remaining: 3.21s
# 26:	learn: 2294.4453710	total: 4.16s	remaining: 11.2s
# 26:	learn: 2306.4179624	total: 4.16s	remaining: 11.2s
# 29:	learn: 2201.2125669	total: 4.46s	remaining: 2.97s
# 28:	learn: 1793.3294330	total: 4.22s	remaining: 3.05s
# 29:	learn: 1765.1855842	total: 4.48s	remaining: 2.99s
# 28:	learn: 1791.2256578	total: 4.44s	remaining: 3.22s
# 29:	learn: 2198.1856593	total: 4.56s	remaining: 3.04s
# 27:	learn: 2271.5492275	total: 4.48s	remaining: 3.52s
# 30:	learn: 2174.0814296	total: 4.56s	remaining: 2.79s
# 27:	learn: 2260.1113654	total: 4.29s	remaining: 11s
# 29:	learn: 1775.8983955	total: 4.33s	remaining: 2.88s
# 27:	learn: 2271.5492275	total: 4.32s	remaining: 11.1s
# 30:	learn: 1750.8793324	total: 4.61s	remaining: 2.82s
# 31:	learn: 2148.3774777	total: 4.66s	remaining: 2.62s
# 30:	learn: 2169.5731000	total: 4.68s	remaining: 2.87s
# 29:	learn: 1775.0110040	total: 4.58s	remaining: 3.05s
# 28:	learn: 2237.4441276	total: 4.61s	remaining: 3.34s
# 28:	learn: 2228.1498150	total: 4.44s	remaining: 10.9s
# 28:	learn: 2237.4441276	total: 4.44s	remaining: 10.9s
# 30:	learn: 1761.1233632	total: 4.48s	remaining: 2.75s
# 31:	learn: 2143.3591729	total: 4.8s	remaining: 2.7s
# 32:	learn: 2123.7357381	total: 4.8s	remaining: 2.47s
# 30:	learn: 1760.4322917	total: 4.71s	remaining: 2.89s
# 29:	learn: 2206.7769748	total: 4.74s	remaining: 3.16s
# 31:	learn: 1738.5853593	total: 4.76s	remaining: 2.68s
# 29:	learn: 2198.1856593	total: 4.55s	remaining: 10.6s
# 31:	learn: 1750.2470861	total: 4.59s	remaining: 2.58s
# 29:	learn: 2206.7769748	total: 4.57s	remaining: 10.7s
# 33:	learn: 2097.9604092	total: 4.92s	remaining: 2.32s
# 32:	learn: 2117.7296473	total: 4.94s	remaining: 2.54s
# 32:	learn: 1729.0331530	total: 4.88s	remaining: 2.51s
# 30:	learn: 2177.7733710	total: 4.88s	remaining: 2.99s
# 31:	learn: 1749.7118931	total: 4.85s	remaining: 2.73s
# 30:	learn: 2169.5731000	total: 4.68s	remaining: 10.4s
# 30:	learn: 2177.7733710	total: 4.7s	remaining: 10.5s
# 32:	learn: 1737.9528520	total: 4.75s	remaining: 2.45s
# 33:	learn: 1720.6985398	total: 5s	remaining: 2.35s
# 34:	learn: 2073.1463461	total: 5.06s	remaining: 2.17s
# 33:	learn: 2095.6014908	total: 5.07s	remaining: 2.39s
# 31:	learn: 2150.7562315	total: 5s	remaining: 2.81s
# 31:	learn: 2143.3591729	total: 4.8s	remaining: 10.2s
# 32:	learn: 1738.3606898	total: 5s	remaining: 2.57s
# 31:	learn: 2150.7562315	total: 4.83s	remaining: 10.3s
# 33:	learn: 1726.9647929	total: 4.86s	remaining: 2.29s
# 34:	learn: 2070.2096515	total: 5.17s	remaining: 2.21s
# 35:	learn: 2049.6370792	total: 5.2s	remaining: 2.02s
# 34:	learn: 1712.6178551	total: 5.14s	remaining: 2.21s
# 32:	learn: 2126.0842362	total: 5.14s	remaining: 2.65s
# 33:	learn: 1730.3092415	total: 5.13s	remaining: 2.41s
# 32:	learn: 2117.7296473	total: 4.94s	remaining: 10s
# 32:	learn: 2126.0842362	total: 4.96s	remaining: 10.1s
# 34:	learn: 1718.4903893	total: 5s	remaining: 2.14s
# 35:	learn: 2046.7093935	total: 5.29s	remaining: 2.06s
# 35:	learn: 1703.6385799	total: 5.28s	remaining: 2.05s
# 36:	learn: 2028.5709464	total: 5.34s	remaining: 1.88s
# 33:	learn: 2095.6014908	total: 5.06s	remaining: 9.83s
# 33:	learn: 2103.2833220	total: 5.29s	remaining: 2.49s
# 34:	learn: 1721.0495033	total: 5.29s	remaining: 2.27s
# 35:	learn: 1710.5416329	total: 5.13s	remaining: 2s
# 33:	learn: 2103.2833220	total: 5.12s	remaining: 9.94s
# 36:	learn: 2025.1325271	total: 5.45s	remaining: 1.92s
# 34:	learn: 2081.8162118	total: 5.43s	remaining: 2.33s
# 37:	learn: 2009.6041031	total: 5.5s	remaining: 1.74s
# 34:	learn: 2070.2096515	total: 5.22s	remaining: 9.7s
# 34:	learn: 2081.8162118	total: 5.22s	remaining: 9.7s
# 36:	learn: 1698.2209192	total: 5.49s	remaining: 1.93s
# 35:	learn: 1713.6447330	total: 5.45s	remaining: 2.12s
# 36:	learn: 1702.7553402	total: 5.29s	remaining: 1.86s
# 37:	learn: 2005.0478907	total: 5.57s	remaining: 1.76s
# 35:	learn: 2046.7093935	total: 5.33s	remaining: 9.48s
# 35:	learn: 2058.8241614	total: 5.55s	remaining: 2.16s
# 38:	learn: 1991.5255849	total: 5.64s	remaining: 1.59s
# 37:	learn: 1695.1757784	total: 5.41s	remaining: 1.71s
# 38:	learn: 1986.1854197	total: 5.69s	remaining: 1.6s
# 35:	learn: 2058.8241614	total: 5.39s	remaining: 9.59s
# 37:	learn: 1691.7805368	total: 5.67s	remaining: 1.79s
# 36:	learn: 1706.5444049	total: 5.63s	remaining: 1.98s
# 36:	learn: 2036.7955398	total: 5.67s	remaining: 1.99s
# 36:	learn: 2025.1325271	total: 5.48s	remaining: 9.33s
# 39:	learn: 1974.2416967	total: 5.77s	remaining: 1.44s
# 36:	learn: 2036.7955398	total: 5.52s	remaining: 9.4s
# 39:	learn: 1968.7243150	total: 5.83s	remaining: 1.46s
# 38:	learn: 1689.1677325	total: 5.55s	remaining: 1.57s
# 37:	learn: 2016.2245748	total: 5.77s	remaining: 1.82s
# 38:	learn: 1685.4975076	total: 5.81s	remaining: 1.64s
# 37:	learn: 1699.4507313	total: 5.77s	remaining: 1.82s
# 37:	learn: 2005.0478907	total: 5.61s	remaining: 9.15s
# 40:	learn: 1957.7800197	total: 5.91s	remaining: 1.3s
# 37:	learn: 2016.2245748	total: 5.65s	remaining: 9.21s
# 40:	learn: 1951.5035355	total: 5.98s	remaining: 1.31s
# 39:	learn: 1683.2972304	total: 5.7s	remaining: 1.43s
# 38:	learn: 1996.3796357	total: 5.9s	remaining: 1.67s
# 39:	learn: 1680.0773000	total: 5.96s	remaining: 1.49s
# 38:	learn: 1693.9547961	total: 5.93s	remaining: 1.67s
# 38:	learn: 1986.1854197	total: 5.76s	remaining: 9.01s
# 38:	learn: 1996.3796357	total: 5.77s	remaining: 9.03s
# 41:	learn: 1942.8106483	total: 6.06s	remaining: 1.15s
# 39:	learn: 1978.6937154	total: 6s	remaining: 1.5s
# 41:	learn: 1936.6193583	total: 6.11s	remaining: 1.16s
# 40:	learn: 1673.5183176	total: 6.07s	remaining: 1.33s
# 40:	learn: 1677.4534068	total: 5.87s	remaining: 1.29s
# 40:	learn: 1961.5494145	total: 6.12s	remaining: 1.34s
# 39:	learn: 1978.6937154	total: 5.9s	remaining: 8.86s
# 42:	learn: 1928.8637363	total: 6.19s	remaining: 1.01s
# 39:	learn: 1968.7243150	total: 5.92s	remaining: 8.88s
# 39:	learn: 1687.9476079	total: 6.1s	remaining: 1.53s
# 42:	learn: 1922.2674979	total: 6.24s	remaining: 1.01s
# 41:	learn: 1672.3726213	total: 6s	remaining: 1.14s
# 41:	learn: 1664.5470551	total: 6.22s	remaining: 1.18s
# 41:	learn: 1945.7702650	total: 6.27s	remaining: 1.19s
# 40:	learn: 1682.3489182	total: 6.24s	remaining: 1.37s
# 40:	learn: 1951.5035355	total: 6.06s	remaining: 8.72s
# 43:	learn: 1915.4053735	total: 6.33s	remaining: 864ms
# 40:	learn: 1961.5494145	total: 6.05s	remaining: 8.71s
# 43:	learn: 1908.7722625	total: 6.39s	remaining: 871ms
# 42:	learn: 1668.4616396	total: 6.13s	remaining: 999ms
# 42:	learn: 1660.8720434	total: 6.36s	remaining: 1.03s
# 42:	learn: 1931.2249989	total: 6.4s	remaining: 1.04s
# 41:	learn: 1945.7702650	total: 6.18s	remaining: 8.54s
# 41:	learn: 1677.6325470	total: 6.38s	remaining: 1.21s
# 41:	learn: 1936.6193583	total: 6.2s	remaining: 8.56s
# 44:	learn: 1896.3458823	total: 6.53s	remaining: 725ms
# 44:	learn: 1901.7180165	total: 6.51s	remaining: 723ms
# 43:	learn: 1663.5695297	total: 6.27s	remaining: 856ms
# 43:	learn: 1657.2227891	total: 6.5s	remaining: 886ms
# 43:	learn: 1917.6117317	total: 6.54s	remaining: 891ms
# 42:	learn: 1931.2249989	total: 6.32s	remaining: 8.37s
# 42:	learn: 1672.3137744	total: 6.52s	remaining: 1.06s
# 42:	learn: 1922.2674979	total: 6.35s	remaining: 8.41s
# 45:	learn: 1883.6135359	total: 6.65s	remaining: 578ms
# 45:	learn: 1889.9062922	total: 6.65s	remaining: 578ms
# 44:	learn: 1659.6562657	total: 6.41s	remaining: 713ms
# 44:	learn: 1652.1550953	total: 6.64s	remaining: 738ms
# 43:	learn: 1917.6117317	total: 6.44s	remaining: 8.19s
# 43:	learn: 1665.8015504	total: 6.66s	remaining: 908ms
# 44:	learn: 1904.9472077	total: 6.7s	remaining: 744ms
# 43:	learn: 1908.7722625	total: 6.49s	remaining: 8.26s
# 46:	learn: 1871.7013737	total: 6.79s	remaining: 433ms
# 46:	learn: 1878.2792835	total: 6.78s	remaining: 433ms
# 45:	learn: 1647.6551170	total: 6.8s	remaining: 591ms
# 45:	learn: 1656.0194979	total: 6.58s	remaining: 572ms
# 44:	learn: 1896.3458823	total: 6.6s	remaining: 8.07s
# 44:	learn: 1904.9472077	total: 6.6s	remaining: 8.07s
# 44:	learn: 1662.2411259	total: 6.81s	remaining: 756ms
# 45:	learn: 1893.1057741	total: 6.85s	remaining: 595ms
# 47:	learn: 1868.2921922	total: 6.93s	remaining: 289ms
# 47:	learn: 1861.5663367	total: 6.95s	remaining: 290ms
# 46:	learn: 1652.2252274	total: 6.71s	remaining: 428ms
# 46:	learn: 1643.2433622	total: 6.94s	remaining: 443ms
# 45:	learn: 1893.1057741	total: 6.73s	remaining: 7.9s
# 45:	learn: 1658.1158330	total: 6.92s	remaining: 602ms
# 46:	learn: 1881.9897148	total: 6.96s	remaining: 444ms
# 45:	learn: 1883.6135359	total: 6.75s	remaining: 7.92s
# 48:	learn: 1858.1497784	total: 7.06s	remaining: 144ms
# 48:	learn: 1852.1369036	total: 7.08s	remaining: 144ms
# 46:	learn: 1881.9897148	total: 6.85s	remaining: 7.72s
# 47:	learn: 1640.4646333	total: 7.09s	remaining: 295ms
# 47:	learn: 1871.3396429	total: 7.09s	remaining: 296ms
# 46:	learn: 1655.5041801	total: 7.07s	remaining: 452ms
# 47:	learn: 1649.5182315	total: 6.91s	remaining: 288ms
# 46:	learn: 1871.7013737	total: 6.9s	remaining: 7.78s
# 49:	learn: 1842.6980756	total: 7.21s	remaining: 0us
# 49:	learn: 1848.9084514	total: 7.21s	remaining: 0us
# 48:	learn: 1861.2850191	total: 7.18s	remaining: 146ms
# 48:	learn: 1635.6039432	total: 7.21s	remaining: 147ms
# 47:	learn: 1871.3396429	total: 6.97s	remaining: 7.56s
# 48:	learn: 1646.0953206	total: 7.04s	remaining: 144ms
# 47:	learn: 1652.3468465	total: 7.21s	remaining: 301ms
# 47:	learn: 1861.5663367	total: 7.03s	remaining: 7.62s
# 49:	learn: 1632.2050757	total: 7.34s	remaining: 0us
# 48:	learn: 1861.2850191	total: 7.12s	remaining: 7.41s
# 49:	learn: 1852.1306264	total: 7.36s	remaining: 0us
# 48:	learn: 1852.1369036	total: 7.18s	remaining: 7.48s
# 49:	learn: 1641.8610019	total: 7.21s	remaining: 0us
# 48:	learn: 1649.7365046	total: 7.4s	remaining: 151ms
# 49:	learn: 1852.1306264	total: 7.28s	remaining: 7.28s
# 49:	learn: 1646.4113858	total: 7.5s	remaining: 0us
# 49:	learn: 1842.6980756	total: 7.32s	remaining: 7.32s
# 50:	learn: 1843.5751375	total: 7.39s	remaining: 7.1s
# 50:	learn: 1834.0148900	total: 7.47s	remaining: 7.17s
# 51:	learn: 1834.2976901	total: 7.55s	remaining: 6.96s
# 51:	learn: 1825.7144144	total: 7.58s	remaining: 6.99s
# 52:	learn: 1817.6610112	total: 7.67s	remaining: 6.81s
# 0:	learn: 4497.4043066	total: 122ms	remaining: 12.1s
# 52:	learn: 1827.0534316	total: 7.71s	remaining: 6.84s
# 0:	learn: 4314.2564331	total: 184ms	remaining: 18.2s
# 53:	learn: 1818.3426976	total: 7.81s	remaining: 6.65s
# 53:	learn: 1809.9448341	total: 7.82s	remaining: 6.66s
# 1:	learn: 4336.0033555	total: 260ms	remaining: 12.8s
# 54:	learn: 1810.2031657	total: 7.98s	remaining: 6.53s
# 2:	learn: 4184.9662865	total: 422ms	remaining: 13.6s
# 1:	learn: 4012.1549845	total: 368ms	remaining: 18s
# 54:	learn: 1802.7693515	total: 8s	remaining: 6.55s
# 0:	learn: 4327.2260118	total: 147ms	remaining: 14.5s
# 0:	learn: 4320.0193883	total: 253ms	remaining: 25s
# 55:	learn: 1802.7803071	total: 8.11s	remaining: 6.37s
# 55:	learn: 1796.4916827	total: 8.15s	remaining: 6.4s
# 2:	learn: 3746.6241966	total: 529ms	remaining: 17.1s
# 3:	learn: 4040.7480353	total: 637ms	remaining: 15.3s
# 0:	learn: 4488.4193543	total: 268ms	remaining: 13.1s
# 1:	learn: 4027.8279876	total: 346ms	remaining: 16.9s
# 56:	learn: 1796.6772261	total: 8.26s	remaining: 6.23s
# 0:	learn: 4484.4357619	total: 359ms	remaining: 17.6s
# 1:	learn: 4019.4832554	total: 523ms	remaining: 25.6s
# 56:	learn: 1791.0213343	total: 8.3s	remaining: 6.26s
# 3:	learn: 3508.5363177	total: 760ms	remaining: 18.2s
# 4:	learn: 3905.9541296	total: 832ms	remaining: 15.8s
# 2:	learn: 3763.5680491	total: 571ms	remaining: 18.5s
# 57:	learn: 1791.2001538	total: 8.46s	remaining: 6.13s
# 1:	learn: 4325.7079412	total: 563ms	remaining: 13.5s
# 57:	learn: 1784.8267110	total: 8.51s	remaining: 6.16s
# 2:	learn: 3749.8643565	total: 735ms	remaining: 23.8s
# 1:	learn: 4319.7350972	total: 604ms	remaining: 14.5s
# 5:	learn: 3780.2548825	total: 993ms	remaining: 15.6s
# 4:	learn: 3304.9459737	total: 946ms	remaining: 18s
# 3:	learn: 3524.8559525	total: 721ms	remaining: 17.3s
# 58:	learn: 1782.2332630	total: 8.65s	remaining: 6.01s
# 58:	learn: 1779.0552277	total: 8.68s	remaining: 6.03s
# 3:	learn: 3511.6076526	total: 958ms	remaining: 23s
# 6:	learn: 3660.1846753	total: 1.18s	remaining: 15.6s
# 4:	learn: 3317.1311555	total: 900ms	remaining: 17.1s
# 5:	learn: 3123.8053889	total: 1.16s	remaining: 18.2s
# 2:	learn: 4167.1570435	total: 858ms	remaining: 13.4s
# 2:	learn: 4173.8499779	total: 875ms	remaining: 13.7s
# 59:	learn: 1774.6047550	total: 8.85s	remaining: 5.9s
# 59:	learn: 1771.1357590	total: 8.86s	remaining: 5.91s
# 6:	learn: 2969.7529153	total: 1.3s	remaining: 17.3s
# 5:	learn: 3136.4442243	total: 1.05s	remaining: 16.4s
# 4:	learn: 3303.1534928	total: 1.17s	remaining: 22.2s
# 60:	learn: 1762.9498574	total: 8.99s	remaining: 5.75s
# 7:	learn: 3548.7647149	total: 1.43s	remaining: 16.4s
# 60:	learn: 1766.3798313	total: 9.02s	remaining: 5.76s
# 3:	learn: 4030.4306879	total: 1.09s	remaining: 12.5s
# 3:	learn: 4023.3246278	total: 1.15s	remaining: 13.2s
# 7:	learn: 2830.4901940	total: 1.46s	remaining: 16.8s
# 5:	learn: 3118.9979909	total: 1.32s	remaining: 20.6s
# 6:	learn: 2979.8847258	total: 1.24s	remaining: 16.4s
# 4:	learn: 3896.6754195	total: 1.23s	remaining: 11.1s
# 61:	learn: 1755.4173993	total: 9.18s	remaining: 5.63s
# 8:	learn: 3442.1083603	total: 1.61s	remaining: 16.3s
# 61:	learn: 1759.9022912	total: 9.18s	remaining: 5.63s
# 8:	learn: 2706.9625808	total: 1.59s	remaining: 16.1s
# 6:	learn: 2962.2728737	total: 1.47s	remaining: 19.6s
# 4:	learn: 3888.8122846	total: 1.38s	remaining: 12.4s
# 7:	learn: 2836.8989130	total: 1.43s	remaining: 16.5s
# 62:	learn: 1748.9534815	total: 9.36s	remaining: 5.5s
# 62:	learn: 1752.6030874	total: 9.37s	remaining: 5.5s
# 9:	learn: 3341.3053062	total: 1.81s	remaining: 16.3s
# 9:	learn: 2598.2551088	total: 1.79s	remaining: 16.1s
# 7:	learn: 2822.7628246	total: 1.67s	remaining: 19.2s
# 5:	learn: 3769.0873822	total: 1.5s	remaining: 11s
# 8:	learn: 2712.3094641	total: 1.58s	remaining: 16s
# 10:	learn: 3248.3008829	total: 1.94s	remaining: 15.7s
# 5:	learn: 3759.6597348	total: 1.63s	remaining: 11.9s
# 63:	learn: 1745.8840522	total: 9.55s	remaining: 5.37s
# 10:	learn: 2504.7944939	total: 1.94s	remaining: 15.7s
# 63:	learn: 1742.5639935	total: 9.56s	remaining: 5.38s
# 9:	learn: 2608.9192705	total: 1.71s	remaining: 15.3s
# 8:	learn: 2701.8847920	total: 1.83s	remaining: 18.6s
# 11:	learn: 3160.7663739	total: 2.09s	remaining: 15.3s
# 10:	learn: 2501.3972430	total: 1.81s	remaining: 14.7s
# 6:	learn: 3646.6989840	total: 1.76s	remaining: 10.8s
# 64:	learn: 1737.6398173	total: 9.72s	remaining: 5.23s
# 11:	learn: 2408.5789533	total: 2.14s	remaining: 15.7s
# 64:	learn: 1739.2719344	total: 9.75s	remaining: 5.25s
# 9:	learn: 2596.5673463	total: 2s	remaining: 18s
# 6:	learn: 3637.9425113	total: 1.89s	remaining: 11.6s
# 65:	learn: 1731.8281142	total: 9.83s	remaining: 5.07s
# 12:	learn: 3080.3527643	total: 2.26s	remaining: 15.1s
# 11:	learn: 2407.9522491	total: 1.97s	remaining: 14.4s
# 65:	learn: 1733.5460589	total: 9.89s	remaining: 5.1s
# 10:	learn: 2507.0227598	total: 2.14s	remaining: 17.3s
# 7:	learn: 3532.6541903	total: 2.01s	remaining: 10.6s
# 12:	learn: 2321.4020169	total: 2.34s	remaining: 15.6s
# 66:	learn: 1726.7556564	total: 9.97s	remaining: 4.91s
# 12:	learn: 2323.1402293	total: 2.11s	remaining: 14.1s
# 13:	learn: 3004.1141163	total: 2.44s	remaining: 15s
# 11:	learn: 2409.3228391	total: 2.29s	remaining: 16.8s
# 66:	learn: 1728.2477130	total: 10.1s	remaining: 4.96s
# 13:	learn: 2246.9366626	total: 2.5s	remaining: 15.4s
# 13:	learn: 2254.2382096	total: 2.26s	remaining: 13.9s
# 67:	learn: 1721.5180587	total: 10.2s	remaining: 4.78s
# 14:	learn: 2932.9222241	total: 2.59s	remaining: 14.7s
# 7:	learn: 3522.3535886	total: 2.24s	remaining: 11.8s
# 12:	learn: 2326.2778546	total: 2.41s	remaining: 16.1s
# 8:	learn: 3422.9175180	total: 2.26s	remaining: 10.3s
# 67:	learn: 1723.2915625	total: 10.2s	remaining: 4.8s
# 14:	learn: 2185.2251157	total: 2.63s	remaining: 14.9s
# 15:	learn: 2864.4624173	total: 2.73s	remaining: 14.3s
# 13:	learn: 2255.2315719	total: 2.54s	remaining: 15.6s
# 68:	learn: 1717.2741155	total: 10.3s	remaining: 4.64s
# 14:	learn: 2191.1957312	total: 2.45s	remaining: 13.9s
# 15:	learn: 2131.9018233	total: 2.77s	remaining: 14.5s
# 68:	learn: 1718.8452714	total: 10.4s	remaining: 4.67s
# 16:	learn: 2802.6711868	total: 2.85s	remaining: 13.9s
# 8:	learn: 3413.6315062	total: 2.54s	remaining: 11.6s
# 9:	learn: 3322.4261164	total: 2.53s	remaining: 10.1s
# 14:	learn: 2193.8369627	total: 2.7s	remaining: 15.3s
# 69:	learn: 1712.3070854	total: 10.5s	remaining: 4.49s
# 15:	learn: 2137.7465348	total: 2.61s	remaining: 13.7s
# 16:	learn: 2086.9726661	total: 2.89s	remaining: 14.1s
# 69:	learn: 1715.4325548	total: 10.5s	remaining: 4.51s
# 17:	learn: 2741.9293309	total: 3s	remaining: 13.7s
# 15:	learn: 2141.5115144	total: 2.81s	remaining: 14.8s
# 17:	learn: 2039.7501385	total: 3.01s	remaining: 13.7s
# 16:	learn: 2085.1987664	total: 2.78s	remaining: 13.6s
# 70:	learn: 1709.2598711	total: 10.7s	remaining: 4.37s
# 10:	learn: 3228.9811919	total: 2.76s	remaining: 9.8s
# 70:	learn: 1710.2951728	total: 10.7s	remaining: 4.37s
# 9:	learn: 3312.9407190	total: 2.79s	remaining: 11.2s
# 18:	learn: 2676.3741282	total: 3.16s	remaining: 13.5s
# 18:	learn: 1997.5429341	total: 3.11s	remaining: 13.3s
# 16:	learn: 2093.9813160	total: 2.97s	remaining: 14.5s
# 71:	learn: 1706.3854235	total: 10.8s	remaining: 4.2s
# 17:	learn: 2038.2763727	total: 2.96s	remaining: 13.5s
# 19:	learn: 2616.4189306	total: 3.28s	remaining: 13.1s
# 71:	learn: 1704.8709656	total: 10.9s	remaining: 4.22s
# 11:	learn: 3142.2892649	total: 2.93s	remaining: 9.29s
# 17:	learn: 2045.0772988	total: 3.1s	remaining: 14.1s
# 19:	learn: 1961.5625570	total: 3.27s	remaining: 13.1s
# 10:	learn: 3220.3292877	total: 2.97s	remaining: 10.5s
# 72:	learn: 1702.5303700	total: 11s	remaining: 4.05s
# 72:	learn: 1700.5242582	total: 11s	remaining: 4.06s
# 18:	learn: 1998.2882146	total: 3.1s	remaining: 13.2s
# 20:	learn: 2560.1127308	total: 3.42s	remaining: 12.9s
# 12:	learn: 3058.2797595	total: 3.13s	remaining: 8.9s
# 20:	learn: 1929.4166439	total: 3.46s	remaining: 13s
# 73:	learn: 1699.1408958	total: 11.1s	remaining: 3.9s
# 18:	learn: 2002.7761010	total: 3.34s	remaining: 14.2s
# 73:	learn: 1697.5633800	total: 11.1s	remaining: 3.92s
# 19:	learn: 1963.1308296	total: 3.27s	remaining: 13.1s
# 11:	learn: 3129.0188724	total: 3.23s	remaining: 10.2s
# 21:	learn: 2507.9625973	total: 3.6s	remaining: 12.8s
# 21:	learn: 1901.2488418	total: 3.59s	remaining: 12.7s
# 74:	learn: 1695.4233188	total: 11.2s	remaining: 3.74s
# 13:	learn: 2978.5944977	total: 3.32s	remaining: 8.55s
# 20:	learn: 1933.1348023	total: 3.41s	remaining: 12.8s
# 19:	learn: 1966.1371450	total: 3.51s	remaining: 14.1s
# 74:	learn: 1694.0246731	total: 11.3s	remaining: 3.77s
# 22:	learn: 2459.5860096	total: 3.77s	remaining: 12.6s
# 22:	learn: 1877.9189060	total: 3.72s	remaining: 12.5s
# 12:	learn: 3044.9309257	total: 3.47s	remaining: 9.88s
# 75:	learn: 1692.3975441	total: 11.4s	remaining: 3.6s
# 20:	learn: 1935.5092810	total: 3.65s	remaining: 13.7s
# 23:	learn: 2413.8956608	total: 3.88s	remaining: 12.3s
# 21:	learn: 1908.4517716	total: 3.57s	remaining: 12.7s
# 23:	learn: 1857.6329464	total: 3.85s	remaining: 12.2s
# 75:	learn: 1690.0910352	total: 11.5s	remaining: 3.63s
# 76:	learn: 1689.1178914	total: 11.5s	remaining: 3.44s
# 14:	learn: 2905.0730376	total: 3.63s	remaining: 8.47s
# 21:	learn: 1908.5480746	total: 3.82s	remaining: 13.5s
# 22:	learn: 1886.3141939	total: 3.72s	remaining: 12.5s
# 24:	learn: 1838.2239328	total: 4s	remaining: 12s
# 24:	learn: 2372.6966687	total: 4.06s	remaining: 12.2s
# 13:	learn: 2965.6898232	total: 3.71s	remaining: 9.54s
# 76:	learn: 1687.2704631	total: 11.7s	remaining: 3.48s
# 77:	learn: 1685.7629530	total: 11.7s	remaining: 3.3s
# 22:	learn: 1883.8838396	total: 3.95s	remaining: 13.2s
# 23:	learn: 1864.9820700	total: 3.86s	remaining: 12.2s
# 25:	learn: 1820.7730298	total: 4.14s	remaining: 11.8s
# 15:	learn: 2834.8456768	total: 3.85s	remaining: 8.19s
# 25:	learn: 2333.7196665	total: 4.23s	remaining: 12s
# 77:	learn: 1683.4519959	total: 11.8s	remaining: 3.33s
# 14:	learn: 2893.5908813	total: 3.91s	remaining: 9.13s
# 24:	learn: 1846.9420890	total: 3.97s	remaining: 11.9s
# 78:	learn: 1682.9190732	total: 11.8s	remaining: 3.15s
# 23:	learn: 1863.5110763	total: 4.09s	remaining: 12.9s
# 26:	learn: 1806.3155759	total: 4.27s	remaining: 11.5s
# 26:	learn: 2296.7676182	total: 4.39s	remaining: 11.9s
# 78:	learn: 1680.7554443	total: 12s	remaining: 3.18s
# 16:	learn: 2769.9471477	total: 4.05s	remaining: 7.87s
# 25:	learn: 1829.7200366	total: 4.12s	remaining: 11.7s
# 79:	learn: 1680.1890658	total: 12s	remaining: 3s
# 24:	learn: 1845.3317305	total: 4.24s	remaining: 12.7s
# 27:	learn: 1793.3189135	total: 4.42s	remaining: 11.4s
# 15:	learn: 2825.2682288	total: 4.14s	remaining: 8.79s
# 26:	learn: 1816.9594523	total: 4.22s	remaining: 11.4s
# 79:	learn: 1677.0781200	total: 12.1s	remaining: 3.03s
# 27:	learn: 2262.1527699	total: 4.54s	remaining: 11.7s
# 25:	learn: 1829.4609166	total: 4.37s	remaining: 12.4s
# 80:	learn: 1677.7624110	total: 12.2s	remaining: 2.85s
# 28:	learn: 1780.7007682	total: 4.55s	remaining: 11.2s
# 17:	learn: 2708.5080546	total: 4.28s	remaining: 7.61s
# 28:	learn: 2230.3292819	total: 4.69s	remaining: 11.5s
# 27:	learn: 1803.4459113	total: 4.39s	remaining: 11.3s
# 80:	learn: 1674.6022899	total: 12.3s	remaining: 2.88s
# 81:	learn: 1674.7673723	total: 12.3s	remaining: 2.7s
# 16:	learn: 2760.8603999	total: 4.38s	remaining: 8.51s
# 26:	learn: 1815.3889914	total: 4.54s	remaining: 12.3s
# 29:	learn: 1765.1855842	total: 4.7s	remaining: 11s
# 29:	learn: 2201.2125669	total: 4.82s	remaining: 11.2s
# 28:	learn: 1793.3294330	total: 4.55s	remaining: 11.1s
# 81:	learn: 1672.7031663	total: 12.5s	remaining: 2.73s
# 18:	learn: 2650.9155691	total: 4.51s	remaining: 7.36s
# 27:	learn: 1802.9221150	total: 4.68s	remaining: 12s
# 82:	learn: 1672.5929248	total: 12.5s	remaining: 2.55s
# 30:	learn: 1750.8793324	total: 4.85s	remaining: 10.8s
# 30:	learn: 2174.0814296	total: 4.94s	remaining: 11s
# 17:	learn: 2699.8219815	total: 4.6s	remaining: 8.18s
# 29:	learn: 1775.8983955	total: 4.69s	remaining: 10.9s
# 28:	learn: 1791.2256578	total: 4.81s	remaining: 11.8s
# 82:	learn: 1669.8169980	total: 12.6s	remaining: 2.58s
# 83:	learn: 1670.0147730	total: 12.6s	remaining: 2.4s
# 31:	learn: 2148.3774777	total: 5.05s	remaining: 10.7s
# 31:	learn: 1738.5853593	total: 5s	remaining: 10.6s
# 19:	learn: 2596.7908451	total: 4.78s	remaining: 7.16s
# 83:	learn: 1667.1958633	total: 12.7s	remaining: 2.42s
# 30:	learn: 1761.1233632	total: 4.84s	remaining: 10.8s
# 29:	learn: 1775.0110040	total: 4.96s	remaining: 11.6s
# 84:	learn: 1666.9060037	total: 12.7s	remaining: 2.25s
# 18:	learn: 2644.3184546	total: 4.82s	remaining: 7.87s
# 32:	learn: 1729.0331530	total: 5.15s	remaining: 10.5s
# 32:	learn: 2123.7357381	total: 5.21s	remaining: 10.6s
# 84:	learn: 1665.2080575	total: 12.9s	remaining: 2.27s
# 85:	learn: 1665.2995560	total: 12.9s	remaining: 2.09s
# 31:	learn: 1750.2470861	total: 4.99s	remaining: 10.6s
# 30:	learn: 1760.4322917	total: 5.11s	remaining: 11.4s
# 33:	learn: 1720.6985398	total: 5.28s	remaining: 10.2s
# 33:	learn: 2097.9604092	total: 5.37s	remaining: 10.4s
# 19:	learn: 2590.9299193	total: 5.02s	remaining: 7.53s
# 20:	learn: 2547.9709366	total: 5.04s	remaining: 6.96s
# 32:	learn: 1737.9528520	total: 5.11s	remaining: 10.4s
# 86:	learn: 1663.6132183	total: 13s	remaining: 1.94s
# 31:	learn: 1749.7118931	total: 5.25s	remaining: 11.2s
# 34:	learn: 1712.6178551	total: 5.44s	remaining: 10.1s
# 85:	learn: 1662.8363825	total: 13.1s	remaining: 2.13s
# 34:	learn: 2073.1463461	total: 5.5s	remaining: 10.2s
# 32:	learn: 1738.3606898	total: 5.38s	remaining: 10.9s
# 20:	learn: 2542.9805041	total: 5.25s	remaining: 7.25s
# 33:	learn: 1726.9647929	total: 5.29s	remaining: 10.3s
# 87:	learn: 1661.8045091	total: 13.2s	remaining: 1.8s
# 35:	learn: 1703.6385799	total: 5.59s	remaining: 9.94s
# 21:	learn: 2493.3199759	total: 5.27s	remaining: 6.71s
# 86:	learn: 1660.8110157	total: 13.2s	remaining: 1.98s
# 35:	learn: 2049.6370792	total: 5.66s	remaining: 10.1s
# 33:	learn: 1730.3092415	total: 5.5s	remaining: 10.7s
# 88:	learn: 1660.1300494	total: 13.3s	remaining: 1.65s
# 34:	learn: 1718.4903893	total: 5.45s	remaining: 10.1s
# 36:	learn: 1698.2209192	total: 5.73s	remaining: 9.75s
# 87:	learn: 1659.0580865	total: 13.4s	remaining: 1.82s
# 36:	learn: 2028.5709464	total: 5.82s	remaining: 9.9s
# 21:	learn: 2488.4899043	total: 5.46s	remaining: 6.95s
# 22:	learn: 2442.2114034	total: 5.51s	remaining: 6.46s
# 37:	learn: 1691.7805368	total: 5.86s	remaining: 9.56s
# 34:	learn: 1721.0495033	total: 5.7s	remaining: 10.6s
# 35:	learn: 1710.5416329	total: 5.62s	remaining: 9.99s
# 89:	learn: 1658.4383696	total: 13.5s	remaining: 1.5s
# 88:	learn: 1657.2193461	total: 13.6s	remaining: 1.68s
# 37:	learn: 2009.6041031	total: 6.01s	remaining: 9.81s
# 22:	learn: 2436.2733127	total: 5.68s	remaining: 6.67s
# 38:	learn: 1685.4975076	total: 5.99s	remaining: 9.37s
# 35:	learn: 1713.6447330	total: 5.86s	remaining: 10.4s
# 36:	learn: 1702.7553402	total: 5.76s	remaining: 9.81s
# 90:	learn: 1656.5446448	total: 13.6s	remaining: 1.35s
# 23:	learn: 2394.3847501	total: 5.74s	remaining: 6.21s
# 89:	learn: 1655.2208346	total: 13.7s	remaining: 1.52s
# 38:	learn: 1991.5255849	total: 6.17s	remaining: 9.64s
# 39:	learn: 1680.0773000	total: 6.14s	remaining: 9.21s
# 37:	learn: 1695.1757784	total: 5.9s	remaining: 9.63s
# 36:	learn: 1706.5444049	total: 6.02s	remaining: 10.3s
# 23:	learn: 2388.5419249	total: 5.89s	remaining: 6.38s
# 91:	learn: 1655.1491561	total: 13.8s	remaining: 1.2s
# 90:	learn: 1652.7289615	total: 13.8s	remaining: 1.37s
# 39:	learn: 1974.2416967	total: 6.3s	remaining: 9.45s
# 40:	learn: 1673.5183176	total: 6.26s	remaining: 9.01s
# 24:	learn: 2349.0261448	total: 5.96s	remaining: 5.96s
# 38:	learn: 1689.1677325	total: 6.04s	remaining: 9.45s
# 91:	learn: 1650.2860643	total: 14s	remaining: 1.21s
# 37:	learn: 1699.4507313	total: 6.19s	remaining: 10.1s
# 92:	learn: 1653.5902846	total: 14s	remaining: 1.05s
# 40:	learn: 1957.7800197	total: 6.45s	remaining: 9.29s
# 41:	learn: 1664.5470551	total: 6.42s	remaining: 8.87s
# 39:	learn: 1683.2972304	total: 6.21s	remaining: 9.32s
# 24:	learn: 2342.9725398	total: 6.18s	remaining: 6.18s
# 25:	learn: 2307.6451534	total: 6.19s	remaining: 5.72s
# 38:	learn: 1693.9547961	total: 6.36s	remaining: 9.95s
# 92:	learn: 1648.4565846	total: 14.2s	remaining: 1.07s
# 41:	learn: 1942.8106483	total: 6.59s	remaining: 9.11s
# 93:	learn: 1651.6679930	total: 14.2s	remaining: 904ms
# 42:	learn: 1660.8720434	total: 6.58s	remaining: 8.72s
# 40:	learn: 1677.4534068	total: 6.36s	remaining: 9.15s
# 39:	learn: 1687.9476079	total: 6.52s	remaining: 9.79s
# 93:	learn: 1646.5121537	total: 14.3s	remaining: 916ms
# 42:	learn: 1928.8637363	total: 6.77s	remaining: 8.98s
# 26:	learn: 2268.0991050	total: 6.4s	remaining: 5.46s
# 94:	learn: 1649.5780118	total: 14.3s	remaining: 755ms
# 25:	learn: 2300.7929703	total: 6.43s	remaining: 5.93s
# 43:	learn: 1657.2227891	total: 6.77s	remaining: 8.61s
# 41:	learn: 1672.3726213	total: 6.51s	remaining: 8.99s
# 43:	learn: 1915.4053735	total: 6.88s	remaining: 8.76s
# 40:	learn: 1682.3489182	total: 6.68s	remaining: 9.62s
# 95:	learn: 1647.9043042	total: 14.5s	remaining: 604ms
# 94:	learn: 1644.7716176	total: 14.5s	remaining: 764ms
# 27:	learn: 2232.6365397	total: 6.6s	remaining: 5.18s
# 42:	learn: 1668.4616396	total: 6.67s	remaining: 8.84s
# 44:	learn: 1652.1550953	total: 6.94s	remaining: 8.48s
# 26:	learn: 2261.8809866	total: 6.66s	remaining: 5.67s
# 44:	learn: 1901.7180165	total: 7.03s	remaining: 8.59s
# 41:	learn: 1677.6325470	total: 6.85s	remaining: 9.45s
# 96:	learn: 1645.6512691	total: 14.6s	remaining: 452ms
# 95:	learn: 1642.7821579	total: 14.7s	remaining: 611ms
# 45:	learn: 1647.6551170	total: 7.08s	remaining: 8.31s
# 43:	learn: 1663.5695297	total: 6.82s	remaining: 8.68s
# 45:	learn: 1889.9062922	total: 7.19s	remaining: 8.44s
# 42:	learn: 1672.3137744	total: 7s	remaining: 9.28s
# 28:	learn: 2197.9870209	total: 6.84s	remaining: 4.95s
# 97:	learn: 1643.9588936	total: 14.8s	remaining: 302ms
# 96:	learn: 1640.9464035	total: 14.8s	remaining: 459ms
# 46:	learn: 1643.2433622	total: 7.23s	remaining: 8.15s
# 27:	learn: 2225.7560655	total: 6.92s	remaining: 5.44s
# 44:	learn: 1659.6562657	total: 6.99s	remaining: 8.55s
# 46:	learn: 1878.2792835	total: 7.34s	remaining: 8.28s
# 43:	learn: 1665.8015504	total: 7.16s	remaining: 9.12s
# 98:	learn: 1642.5030716	total: 15s	remaining: 151ms
# 97:	learn: 1637.4335083	total: 15s	remaining: 306ms
# 45:	learn: 1656.0194979	total: 7.14s	remaining: 8.38s
# 47:	learn: 1640.4646333	total: 7.42s	remaining: 8.04s
# 47:	learn: 1868.2921922	total: 7.48s	remaining: 8.1s
# 29:	learn: 2166.0780347	total: 7.11s	remaining: 4.74s
# 44:	learn: 1662.2411259	total: 7.35s	remaining: 8.98s
# 28:	learn: 2192.3496411	total: 7.22s	remaining: 5.23s
# 98:	learn: 1634.9289771	total: 15.2s	remaining: 153ms
# 46:	learn: 1652.2252274	total: 7.29s	remaining: 8.22s
# 99:	learn: 1640.6366869	total: 15.2s	remaining: 0us
# 48:	learn: 1858.1497784	total: 7.62s	remaining: 7.93s
# 48:	learn: 1635.6039432	total: 7.59s	remaining: 7.9s
# 45:	learn: 1658.1158330	total: 7.46s	remaining: 8.76s
# 30:	learn: 2135.3669023	total: 7.37s	remaining: 4.52s
# 47:	learn: 1649.5182315	total: 7.43s	remaining: 8.05s
# 49:	learn: 1848.9084514	total: 7.77s	remaining: 7.77s
# 99:	learn: 1633.4470610	total: 15.4s	remaining: 0us
# 29:	learn: 2161.2092203	total: 7.46s	remaining: 4.97s
# 49:	learn: 1632.2050757	total: 7.76s	remaining: 7.76s
# 46:	learn: 1655.5041801	total: 7.66s	remaining: 8.64s
# 48:	learn: 1646.0953206	total: 7.62s	remaining: 7.93s
# 50:	learn: 1840.3289909	total: 7.97s	remaining: 7.65s
# 31:	learn: 2107.6551414	total: 7.65s	remaining: 4.3s
# 50:	learn: 1628.9725269	total: 7.97s	remaining: 7.66s
# 47:	learn: 1652.3468465	total: 7.84s	remaining: 8.49s
# 51:	learn: 1831.5358839	total: 8.11s	remaining: 7.48s
# 30:	learn: 2132.1490660	total: 7.79s	remaining: 4.77s
# 49:	learn: 1641.8610019	total: 7.85s	remaining: 7.85s
# 51:	learn: 1625.9940175	total: 8.18s	remaining: 7.55s
# 52:	learn: 1823.4496176	total: 8.24s	remaining: 7.31s
# 48:	learn: 1649.7365046	total: 8.04s	remaining: 8.37s
# 32:	learn: 2082.3120411	total: 7.91s	remaining: 4.07s
# 50:	learn: 1639.7930852	total: 8.02s	remaining: 7.7s
# 0:	learn: 4497.4043066	total: 173ms	remaining: 8.46s
# 52:	learn: 1623.1338870	total: 8.35s	remaining: 7.41s
# 31:	learn: 2104.6881163	total: 8.06s	remaining: 4.53s
# 53:	learn: 1816.6975815	total: 8.43s	remaining: 7.18s
# 49:	learn: 1646.4113858	total: 8.23s	remaining: 8.23s
# 51:	learn: 1636.0933962	total: 8.21s	remaining: 7.57s
# 33:	learn: 2054.1975405	total: 8.19s	remaining: 3.85s
# 0:	learn: 4311.9076943	total: 288ms	remaining: 14.1s
# 52:	learn: 1633.7781663	total: 8.34s	remaining: 7.4s
# 54:	learn: 1808.7661064	total: 8.66s	remaining: 7.09s
# 53:	learn: 1620.5826083	total: 8.61s	remaining: 7.33s
# 50:	learn: 1641.3142966	total: 8.47s	remaining: 8.14s
# 1:	learn: 4335.3580802	total: 544ms	remaining: 13.1s
# 32:	learn: 2077.8332551	total: 8.4s	remaining: 4.33s
# 55:	learn: 1802.6105150	total: 8.83s	remaining: 6.93s
# 51:	learn: 1639.1393234	total: 8.62s	remaining: 7.96s
# 53:	learn: 1631.9879887	total: 8.53s	remaining: 7.27s
# 54:	learn: 1618.5696747	total: 8.79s	remaining: 7.2s
# 34:	learn: 2027.0833157	total: 8.48s	remaining: 3.64s
# 1:	learn: 4006.3483104	total: 618ms	remaining: 14.8s
# 56:	learn: 1793.2603940	total: 8.99s	remaining: 6.79s
# 2:	learn: 4182.2872003	total: 807ms	remaining: 12.7s
# 52:	learn: 1635.3404332	total: 8.81s	remaining: 7.82s
# 54:	learn: 1629.8509396	total: 8.75s	remaining: 7.16s
# 55:	learn: 1615.1968600	total: 9.03s	remaining: 7.1s
# 33:	learn: 2050.0720108	total: 8.74s	remaining: 4.11s
# 35:	learn: 2002.9055858	total: 8.8s	remaining: 3.42s
# 57:	learn: 1784.7787646	total: 9.17s	remaining: 6.64s
# 2:	learn: 3741.7304434	total: 880ms	remaining: 13.8s
# 53:	learn: 1632.5027884	total: 9.04s	remaining: 7.7s
# 56:	learn: 1613.0324924	total: 9.26s	remaining: 6.98s
# 3:	learn: 4038.4876686	total: 1.13s	remaining: 13s
# 55:	learn: 1627.6082437	total: 9.02s	remaining: 7.09s
# 34:	learn: 2023.7492928	total: 9.04s	remaining: 3.87s
# 58:	learn: 1777.0331878	total: 9.43s	remaining: 6.55s
# 36:	learn: 1980.5977597	total: 9.09s	remaining: 3.19s
# 54:	learn: 1630.0669554	total: 9.28s	remaining: 7.59s
# 56:	learn: 1624.3355635	total: 9.19s	remaining: 6.93s
# 3:	learn: 3502.5056254	total: 1.15s	remaining: 13.2s
# 57:	learn: 1610.8132594	total: 9.48s	remaining: 6.86s
# 59:	learn: 1769.0911403	total: 9.56s	remaining: 6.38s
# 4:	learn: 3905.6213403	total: 1.36s	remaining: 12.3s
# 57:	learn: 1620.7981438	total: 9.36s	remaining: 6.78s
# 55:	learn: 1625.8843193	total: 9.47s	remaining: 7.44s
# 60:	learn: 1761.9301477	total: 9.72s	remaining: 6.21s
# 58:	learn: 1608.9513667	total: 9.69s	remaining: 6.73s
# 37:	learn: 1959.2744131	total: 9.39s	remaining: 2.97s
# 35:	learn: 1999.2139359	total: 9.42s	remaining: 3.66s
# 4:	learn: 3289.1258792	total: 1.45s	remaining: 13.1s
# 5:	learn: 3776.4219009	total: 1.62s	remaining: 11.9s
# 56:	learn: 1623.6892644	total: 9.66s	remaining: 7.28s
# 58:	learn: 1619.1221919	total: 9.58s	remaining: 6.66s
# 61:	learn: 1755.4068808	total: 9.9s	remaining: 6.07s
# 59:	learn: 1607.0377489	total: 9.91s	remaining: 6.6s
# 5:	learn: 3104.8183170	total: 1.74s	remaining: 12.8s
# 36:	learn: 1976.4082616	total: 9.75s	remaining: 3.42s
# 57:	learn: 1621.1212285	total: 9.9s	remaining: 7.17s
# 38:	learn: 1939.2532941	total: 9.75s	remaining: 2.75s
# 62:	learn: 1749.3286684	total: 10.1s	remaining: 5.95s
# 59:	learn: 1614.8479501	total: 9.82s	remaining: 6.55s
# 60:	learn: 1604.4916651	total: 10.1s	remaining: 6.45s
# 6:	learn: 3654.6968502	total: 2.01s	remaining: 12.3s
# 58:	learn: 1617.1600018	total: 10s	remaining: 6.98s
# 63:	learn: 1743.7390104	total: 10.3s	remaining: 5.8s
# 60:	learn: 1610.8060970	total: 10s	remaining: 6.4s
# 37:	learn: 1955.2156268	total: 9.99s	remaining: 3.15s
# 39:	learn: 1920.6801191	total: 10s	remaining: 2.51s
# 61:	learn: 1602.2093419	total: 10.3s	remaining: 6.34s
# 59:	learn: 1613.4736200	total: 10.2s	remaining: 6.83s
# 6:	learn: 2944.0025786	total: 2.11s	remaining: 13s
# 7:	learn: 3539.8123714	total: 2.28s	remaining: 12s
# 64:	learn: 1737.7824513	total: 10.5s	remaining: 5.66s
# 61:	learn: 1607.3470932	total: 10.2s	remaining: 6.26s
# 38:	learn: 1935.5346844	total: 10.2s	remaining: 2.88s
# 60:	learn: 1611.1353937	total: 10.4s	remaining: 6.65s
# 62:	learn: 1600.6916325	total: 10.6s	remaining: 6.22s
# 40:	learn: 1903.1962539	total: 10.3s	remaining: 2.26s
# 62:	learn: 1603.8840938	total: 10.4s	remaining: 6.09s
# 65:	learn: 1732.1224335	total: 10.7s	remaining: 5.51s
# 7:	learn: 2804.3498189	total: 2.42s	remaining: 12.7s
# 63:	learn: 1598.4498705	total: 10.8s	remaining: 6.06s
# 61:	learn: 1608.9069821	total: 10.6s	remaining: 6.52s
# 8:	learn: 3431.1087200	total: 2.63s	remaining: 12s
# 39:	learn: 1916.9740451	total: 10.5s	remaining: 2.63s
# 63:	learn: 1600.6922236	total: 10.6s	remaining: 5.95s
# 66:	learn: 1727.0724052	total: 10.9s	remaining: 5.38s
# 41:	learn: 1886.7966511	total: 10.6s	remaining: 2.02s
# 64:	learn: 1597.0458594	total: 11s	remaining: 5.91s
# 62:	learn: 1607.2303354	total: 10.8s	remaining: 6.37s
# 64:	learn: 1599.5099238	total: 10.8s	remaining: 5.8s
# 40:	learn: 1900.1726373	total: 10.8s	remaining: 2.36s
# 67:	learn: 1722.2942979	total: 11.1s	remaining: 5.24s
# 8:	learn: 2681.5782463	total: 2.77s	remaining: 12.6s
# 42:	learn: 1871.7193683	total: 10.8s	remaining: 1.76s
# 9:	learn: 3330.7451148	total: 2.98s	remaining: 11.9s
# 65:	learn: 1594.8321657	total: 11.1s	remaining: 5.74s
# 63:	learn: 1603.3156272	total: 11s	remaining: 6.21s
# 65:	learn: 1595.8914279	total: 11s	remaining: 5.65s
# 68:	learn: 1717.4906503	total: 11.3s	remaining: 5.08s
# 41:	learn: 1884.3279674	total: 11s	remaining: 2.1s
# 66:	learn: 1592.9091130	total: 11.3s	remaining: 5.57s
# 43:	learn: 1857.3928917	total: 11s	remaining: 1.5s
# 66:	learn: 1592.9209526	total: 11.1s	remaining: 5.49s
# 64:	learn: 1600.3049828	total: 11.3s	remaining: 6.07s
# 9:	learn: 2555.8820059	total: 3.12s	remaining: 12.5s
# 10:	learn: 3236.2096481	total: 3.29s	remaining: 11.6s
# 69:	learn: 1713.8503472	total: 11.5s	remaining: 4.93s
# 67:	learn: 1591.1576527	total: 11.6s	remaining: 5.44s
# 67:	learn: 1591.3604753	total: 11.4s	remaining: 5.35s
# 65:	learn: 1598.2747241	total: 11.5s	remaining: 5.93s
# 42:	learn: 1869.7684681	total: 11.4s	remaining: 1.85s
# 70:	learn: 1709.9083371	total: 11.7s	remaining: 4.79s
# 10:	learn: 2445.3645579	total: 3.42s	remaining: 12.1s
# 11:	learn: 3148.4983989	total: 3.58s	remaining: 11.3s
# 44:	learn: 1844.5016874	total: 11.4s	remaining: 1.27s
# 68:	learn: 1587.6599766	total: 11.8s	remaining: 5.29s
# 68:	learn: 1589.0431750	total: 11.6s	remaining: 5.2s
# 71:	learn: 1705.1484736	total: 11.9s	remaining: 4.64s
# 66:	learn: 1595.8850819	total: 11.8s	remaining: 5.79s
# 12:	learn: 3064.6215488	total: 3.86s	remaining: 11s
# 69:	learn: 1585.6074142	total: 12s	remaining: 5.14s
# 43:	learn: 1856.2501871	total: 11.7s	remaining: 1.6s
# 69:	learn: 1586.9365593	total: 11.8s	remaining: 5.05s
# 67:	learn: 1592.7820335	total: 11.9s	remaining: 5.61s
# 45:	learn: 1831.8073406	total: 11.8s	remaining: 1.02s
# 11:	learn: 2350.8747972	total: 3.78s	remaining: 12s
# 72:	learn: 1701.6210062	total: 12.2s	remaining: 4.5s
# 70:	learn: 1584.3310241	total: 12.2s	remaining: 4.99s
# ...
# 46:	learn: 1514.0979036	total: 1m 33s	remaining: 1m 45s
# 90:	learn: 1514.4680874	total: 3m 51s	remaining: 22.9s
# 65:	learn: 1449.0044934	total: 2m 33s	remaining: 1m 18s
# 48:	learn: 1511.8873589	total: 1m 41s	remaining: 1m 45s
# 68:	learn: 1617.0708683	total: 2m 37s	remaining: 1m 10s
# 92:	learn: 1508.6756541	total: 3m 55s	remaining: 17.7s
# 47:	learn: 1508.5315298	total: 1m 35s	remaining: 1m 43s
# 91:	learn: 1511.7255367	total: 3m 53s	remaining: 20.3s
# 66:	learn: 1447.2189199	total: 2m 35s	remaining: 1m 16s
# 69:	learn: 1610.7275507	total: 2m 39s	remaining: 1m 8s
# 49:	learn: 1508.1197641	total: 1m 43s	remaining: 1m 43s
# 48:	learn: 1503.5493173	total: 1m 38s	remaining: 1m 42s
# 93:	learn: 1505.8453488	total: 3m 57s	remaining: 15.2s
# 92:	learn: 1508.7591435	total: 3m 55s	remaining: 17.7s
# 67:	learn: 1445.6746391	total: 2m 37s	remaining: 1m 14s
# 70:	learn: 1605.3525358	total: 2m 41s	remaining: 1m 5s
# 50:	learn: 1502.5904003	total: 1m 45s	remaining: 1m 41s
# 94:	learn: 1503.4993900	total: 3m 59s	remaining: 12.6s
# 49:	learn: 1500.3487195	total: 1m 40s	remaining: 1m 40s
# 93:	learn: 1506.0392142	total: 3m 57s	remaining: 15.2s
# 68:	learn: 1442.0545281	total: 2m 39s	remaining: 1m 11s
# 69:	learn: 1441.9419206	total: 2m 39s	remaining: 1m 8s
# 71:	learn: 1599.5626693	total: 2m 43s	remaining: 1m 3s
# 51:	learn: 1498.3116000	total: 1m 47s	remaining: 1m 39s
# 50:	learn: 1496.4047650	total: 1m 42s	remaining: 1m 38s
# 95:	learn: 1501.0950455	total: 4m 1s	remaining: 10.1s
# 94:	learn: 1503.5954261	total: 3m 59s	remaining: 12.6s
# 70:	learn: 1439.4666098	total: 2m 41s	remaining: 1m 6s
# 72:	learn: 1594.2156991	total: 2m 45s	remaining: 1m 1s
# 52:	learn: 1495.2168863	total: 1m 49s	remaining: 1m 37s
# 51:	learn: 1492.1080496	total: 1m 44s	remaining: 1m 36s
# 96:	learn: 1499.0256349	total: 4m 3s	remaining: 7.54s
# 95:	learn: 1501.0864136	total: 4m 2s	remaining: 10.1s
# 73:	learn: 1589.2476404	total: 2m 47s	remaining: 58.8s
# 71:	learn: 1436.4052896	total: 2m 44s	remaining: 1m 3s
# 72:	learn: 1436.3564790	total: 2m 44s	remaining: 1m
# 53:	learn: 1488.8690648	total: 1m 52s	remaining: 1m 35s
# 52:	learn: 1489.4899294	total: 1m 46s	remaining: 1m 34s
# 97:	learn: 1496.9125076	total: 4m 6s	remaining: 5.02s
# 96:	learn: 1498.6251159	total: 4m 4s	remaining: 7.55s
# 73:	learn: 1433.8465282	total: 2m 46s	remaining: 58.4s
# 74:	learn: 1584.6306985	total: 2m 49s	remaining: 56.5s
# 53:	learn: 1485.4741261	total: 1m 48s	remaining: 1m 32s
# 54:	learn: 1483.9772848	total: 1m 54s	remaining: 1m 33s
# 98:	learn: 1494.7861306	total: 4m 8s	remaining: 2.51s
# 97:	learn: 1495.5894950	total: 4m 6s	remaining: 5.02s
# 75:	learn: 1579.6336739	total: 2m 51s	remaining: 54.2s
# 74:	learn: 1430.5234934	total: 2m 48s	remaining: 56.1s
# 54:	learn: 1482.6311325	total: 1m 50s	remaining: 1m 30s
# 99:	learn: 1492.5370327	total: 4m 10s	remaining: 0us
# 55:	learn: 1480.1612705	total: 1m 56s	remaining: 1m 31s
# 98:	learn: 1494.1326045	total: 4m 8s	remaining: 2.51s
# 75:	learn: 1428.6133860	total: 2m 50s	remaining: 53.8s
# 76:	learn: 1575.5063069	total: 2m 53s	remaining: 51.9s
# 55:	learn: 1480.3685715	total: 1m 52s	remaining: 1m 28s
# 56:	learn: 1476.6486611	total: 1m 58s	remaining: 1m 29s
# 57:	learn: 1476.4925591	total: 1m 58s	remaining: 1m 25s
# 99:	learn: 1492.2260089	total: 4m 10s	remaining: 0us
# 76:	learn: 1425.8297279	total: 2m 52s	remaining: 51.5s
# 77:	learn: 1571.5586519	total: 2m 55s	remaining: 49.5s
# 56:	learn: 1473.9997242	total: 1m 54s	remaining: 1m 26s
# 58:	learn: 1471.1753589	total: 2m	remaining: 1m 23s
# 78:	learn: 1567.4141523	total: 2m 57s	remaining: 47.1s
# 77:	learn: 1423.1144441	total: 2m 53s	remaining: 49s
# 78:	learn: 1423.0812361	total: 2m 53s	remaining: 46.2s
# 57:	learn: 1471.7093625	total: 1m 55s	remaining: 1m 23s
# 59:	learn: 1467.6794274	total: 2m 1s	remaining: 1m 21s
# 79:	learn: 1420.7442669	total: 2m 55s	remaining: 43.8s
# 79:	learn: 1563.3287976	total: 2m 58s	remaining: 44.6s
# 58:	learn: 1467.6294571	total: 1m 56s	remaining: 1m 21s
# 60:	learn: 1462.9553165	total: 2m 3s	remaining: 1m 18s
# 80:	learn: 1418.3176189	total: 2m 56s	remaining: 41.4s
# 80:	learn: 1559.5293308	total: 2m 59s	remaining: 42.1s
# 59:	learn: 1464.9488299	total: 1m 58s	remaining: 1m 18s
# 61:	learn: 1459.9950962	total: 2m 4s	remaining: 1m 16s
# 81:	learn: 1416.0152689	total: 2m 57s	remaining: 39s
# 81:	learn: 1555.5868652	total: 3m	remaining: 39.7s
# 82:	learn: 1554.7862095	total: 3m	remaining: 37.1s
# 60:	learn: 1461.9736835	total: 1m 59s	remaining: 1m 16s
# 62:	learn: 1456.1379744	total: 2m 5s	remaining: 1m 13s
# 83:	learn: 1551.2408285	total: 3m 1s	remaining: 34.7s
# 82:	learn: 1414.3446892	total: 2m 58s	remaining: 36.6s
# 61:	learn: 1457.6290697	total: 2m	remaining: 1m 13s
# 63:	learn: 1453.4000325	total: 2m 6s	remaining: 1m 11s
# 84:	learn: 1547.6231875	total: 3m 3s	remaining: 32.3s
# 83:	learn: 1412.4616810	total: 2m 59s	remaining: 34.3s
# 62:	learn: 1453.7336649	total: 2m 1s	remaining: 1m 11s
# 64:	learn: 1449.7324550	total: 2m 7s	remaining: 1m 8s
# 85:	learn: 1543.3721349	total: 3m 4s	remaining: 30s
# 84:	learn: 1410.2343972	total: 3m 1s	remaining: 32s
# 63:	learn: 1452.1272670	total: 2m 2s	remaining: 1m 8s
# 65:	learn: 1447.3279057	total: 2m 9s	remaining: 1m 6s
# 86:	learn: 1539.4770149	total: 3m 5s	remaining: 27.7s
# 85:	learn: 1408.5401336	total: 3m 2s	remaining: 29.7s
# 64:	learn: 1447.5881915	total: 2m 3s	remaining: 1m 6s
# 66:	learn: 1444.3728368	total: 2m 10s	remaining: 1m 4s
# 87:	learn: 1536.0287816	total: 3m 6s	remaining: 25.4s
# 86:	learn: 1406.7347578	total: 3m 3s	remaining: 27.4s
# 65:	learn: 1444.4773937	total: 2m 4s	remaining: 1m 4s
# 67:	learn: 1441.9026432	total: 2m 11s	remaining: 1m 1s
# 88:	learn: 1532.4069741	total: 3m 7s	remaining: 23.2s
# 87:	learn: 1402.4693236	total: 3m 4s	remaining: 25.1s
# 66:	learn: 1442.2838497	total: 2m 5s	remaining: 1m 2s
# 68:	learn: 1436.5051646	total: 2m 12s	remaining: 59.4s
# 89:	learn: 1530.0194114	total: 3m 8s	remaining: 20.9s
# 88:	learn: 1399.6145383	total: 3m 5s	remaining: 22.9s
# 89:	learn: 1399.5749068	total: 3m 5s	remaining: 20.6s
# 67:	learn: 1438.9765782	total: 2m 6s	remaining: 59.7s
# 69:	learn: 1433.1520641	total: 2m 13s	remaining: 57.2s
# 90:	learn: 1526.8977604	total: 3m 9s	remaining: 18.7s
# 90:	learn: 1396.2761716	total: 3m 6s	remaining: 18.5s
# 68:	learn: 1436.7820540	total: 2m 8s	remaining: 57.5s
# 91:	learn: 1523.0084364	total: 3m 10s	remaining: 16.6s
# 70:	learn: 1430.1141995	total: 2m 14s	remaining: 55.1s
# 91:	learn: 1393.4996512	total: 3m 8s	remaining: 16.3s
# 69:	learn: 1432.0189126	total: 2m 9s	remaining: 55.4s
# 70:	learn: 1431.9284672	total: 2m 9s	remaining: 52.8s
# 92:	learn: 1519.7001851	total: 3m 11s	remaining: 14.4s
# 71:	learn: 1427.5643437	total: 2m 16s	remaining: 52.9s
# 92:	learn: 1390.5827408	total: 3m 9s	remaining: 14.2s
# 71:	learn: 1428.1953133	total: 2m 10s	remaining: 50.8s
# 93:	learn: 1515.6059418	total: 3m 13s	remaining: 12.3s
# 72:	learn: 1424.6926025	total: 2m 17s	remaining: 50.8s
# 93:	learn: 1387.1426387	total: 3m 10s	remaining: 12.2s
# 72:	learn: 1425.3751698	total: 2m 11s	remaining: 48.7s
# 94:	learn: 1513.2784033	total: 3m 14s	remaining: 10.2s
# 73:	learn: 1423.1661329	total: 2m 18s	remaining: 48.7s
# 94:	learn: 1385.0744676	total: 3m 11s	remaining: 10.1s
# 73:	learn: 1423.2511742	total: 2m 12s	remaining: 46.7s
# 95:	learn: 1511.4324226	total: 3m 15s	remaining: 8.13s
# 74:	learn: 1420.4967099	total: 2m 19s	remaining: 46.5s
# 95:	learn: 1383.5149953	total: 3m 12s	remaining: 8.03s
# 74:	learn: 1419.0954304	total: 2m 13s	remaining: 44.6s
# 96:	learn: 1508.0723971	total: 3m 16s	remaining: 6.07s
# 75:	learn: 1417.1140685	total: 2m 20s	remaining: 44.4s
# 96:	learn: 1380.2693859	total: 3m 13s	remaining: 6s
# 75:	learn: 1416.0716997	total: 2m 15s	remaining: 42.7s
# 97:	learn: 1506.1123371	total: 3m 17s	remaining: 4.03s
# 76:	learn: 1414.8673640	total: 2m 21s	remaining: 42.4s
# 76:	learn: 1414.6569972	total: 2m 16s	remaining: 40.7s
# 97:	learn: 1376.8754713	total: 3m 15s	remaining: 3.98s
# 98:	learn: 1503.6098947	total: 3m 18s	remaining: 2.01s
# 77:	learn: 1413.2028572	total: 2m 22s	remaining: 40.3s
# 77:	learn: 1412.3610004	total: 2m 17s	remaining: 38.7s
# 98:	learn: 1375.9214694	total: 3m 16s	remaining: 1.98s
# 99:	learn: 1500.7952066	total: 3m 19s	remaining: 0us
# 78:	learn: 1411.2837638	total: 2m 24s	remaining: 38.3s
# 78:	learn: 1410.3012487	total: 2m 18s	remaining: 36.8s
# 99:	learn: 1373.8456238	total: 3m 17s	remaining: 0us
# 79:	learn: 1407.9220671	total: 2m 25s	remaining: 36.3s
# 79:	learn: 1407.5155718	total: 2m 19s	remaining: 34.8s
# 80:	learn: 1405.5072645	total: 2m 25s	remaining: 34.2s
# 80:	learn: 1406.1625560	total: 2m 19s	remaining: 32.8s
# 81:	learn: 1406.1126290	total: 2m 19s	remaining: 30.7s
# 81:	learn: 1403.8407101	total: 2m 26s	remaining: 32.1s
# 82:	learn: 1404.0390771	total: 2m 20s	remaining: 28.8s
# 82:	learn: 1400.6520703	total: 2m 26s	remaining: 30.1s
# 83:	learn: 1401.1704171	total: 2m 21s	remaining: 26.9s
# 83:	learn: 1398.7081231	total: 2m 27s	remaining: 28.1s
# 84:	learn: 1398.7593706	total: 2m 21s	remaining: 25s
# 84:	learn: 1396.0700730	total: 2m 27s	remaining: 26.1s
# 85:	learn: 1394.1215017	total: 2m 22s	remaining: 23.1s
# 85:	learn: 1393.8312764	total: 2m 28s	remaining: 24.2s
# 86:	learn: 1389.2614912	total: 2m 22s	remaining: 21.3s
# 86:	learn: 1392.6701996	total: 2m 29s	remaining: 22.3s
# 87:	learn: 1385.8100352	total: 2m 23s	remaining: 19.5s
# 88:	learn: 1385.7678953	total: 2m 23s	remaining: 17.7s
# 87:	learn: 1390.3069832	total: 2m 29s	remaining: 20.4s
# 89:	learn: 1384.3711968	total: 2m 23s	remaining: 16s
# 88:	learn: 1386.5740222	total: 2m 30s	remaining: 18.6s
# 90:	learn: 1381.5188059	total: 2m 24s	remaining: 14.3s
# 89:	learn: 1384.2239927	total: 2m 30s	remaining: 16.7s
# 91:	learn: 1379.8352334	total: 2m 24s	remaining: 12.6s
# 90:	learn: 1383.2186300	total: 2m 31s	remaining: 15s
# 92:	learn: 1376.7729075	total: 2m 25s	remaining: 10.9s
# 91:	learn: 1379.0118309	total: 2m 31s	remaining: 13.2s
# 93:	learn: 1374.8187322	total: 2m 25s	remaining: 9.32s
# 92:	learn: 1374.4747728	total: 2m 32s	remaining: 11.5s
# 94:	learn: 1372.3471565	total: 2m 26s	remaining: 7.71s
# 93:	learn: 1372.0986029	total: 2m 32s	remaining: 9.76s
# 95:	learn: 1369.9324592	total: 2m 27s	remaining: 6.13s
# 94:	learn: 1369.8169588	total: 2m 33s	remaining: 8.08s
# 96:	learn: 1366.8731911	total: 2m 27s	remaining: 4.57s
# 95:	learn: 1367.4572439	total: 2m 34s	remaining: 6.42s
# 97:	learn: 1364.6979808	total: 2m 28s	remaining: 3.02s
# 98:	learn: 1364.6391888	total: 2m 28s	remaining: 1.5s
# 96:	learn: 1363.6339084	total: 2m 34s	remaining: 4.78s
# 99:	learn: 1362.3838047	total: 2m 28s	remaining: 0us
# 97:	learn: 1360.9728701	total: 2m 35s	remaining: 3.17s
# 98:	learn: 1360.9606952	total: 2m 35s	remaining: 1.57s
# 99:	learn: 1356.5441735	total: 2m 35s	remaining: 0us
# 0:	learn: 4316.9479010	total: 298ms	remaining: 29.5s
# 1:	learn: 4011.9866665	total: 581ms	remaining: 28.5s
# 2:	learn: 3738.2479451	total: 847ms	remaining: 27.4s
# 3:	learn: 3495.4413464	total: 1.11s	remaining: 26.8s
# 4:	learn: 3279.9079621	total: 1.37s	remaining: 26s
# 5:	learn: 3092.9485007	total: 1.64s	remaining: 25.7s
# 6:	learn: 2932.7653812	total: 1.94s	remaining: 25.8s
# 7:	learn: 2786.8143019	total: 2.23s	remaining: 25.6s
# 8:	learn: 2659.6442253	total: 2.49s	remaining: 25.2s
# 9:	learn: 2549.2512863	total: 2.75s	remaining: 24.8s
# 10:	learn: 2454.0373759	total: 3.03s	remaining: 24.5s
# 11:	learn: 2354.8396381	total: 3.29s	remaining: 24.2s
# 12:	learn: 2265.5706382	total: 3.58s	remaining: 24s
# 13:	learn: 2187.6463765	total: 3.84s	remaining: 23.6s
# 14:	learn: 2118.6340916	total: 4.09s	remaining: 23.2s
# 15:	learn: 2062.0081628	total: 4.36s	remaining: 22.9s
# 16:	learn: 2010.1582760	total: 4.66s	remaining: 22.7s
# 17:	learn: 1959.4437187	total: 4.93s	remaining: 22.5s
# 18:	learn: 1916.5903952	total: 5.24s	remaining: 22.3s
# 19:	learn: 1879.3468068	total: 5.5s	remaining: 22s
# 20:	learn: 1845.5612024	total: 5.77s	remaining: 21.7s
# 21:	learn: 1817.1433604	total: 6.05s	remaining: 21.5s
# 22:	learn: 1790.6970112	total: 6.32s	remaining: 21.1s
# 23:	learn: 1768.1282001	total: 6.57s	remaining: 20.8s
# 24:	learn: 1748.5054421	total: 6.84s	remaining: 20.5s
# 25:	learn: 1731.0516339	total: 7.11s	remaining: 20.2s
# 26:	learn: 1715.5265979	total: 7.37s	remaining: 19.9s
# 27:	learn: 1702.5326109	total: 7.63s	remaining: 19.6s
# 28:	learn: 1690.4058950	total: 7.9s	remaining: 19.3s
# 29:	learn: 1678.4218803	total: 8.19s	remaining: 19.1s
# 30:	learn: 1660.9449836	total: 8.47s	remaining: 18.8s
# 31:	learn: 1644.5621777	total: 8.75s	remaining: 18.6s
# 32:	learn: 1631.7832459	total: 9.05s	remaining: 18.4s
# 33:	learn: 1620.0052416	total: 9.32s	remaining: 18.1s
# 34:	learn: 1608.1347107	total: 9.59s	remaining: 17.8s
# 35:	learn: 1598.0819150	total: 9.86s	remaining: 17.5s
# 36:	learn: 1588.7753300	total: 10.1s	remaining: 17.2s
# 37:	learn: 1581.3445636	total: 10.4s	remaining: 17s
# 38:	learn: 1574.9939789	total: 10.7s	remaining: 16.7s
# 39:	learn: 1567.0872487	total: 10.9s	remaining: 16.4s
# 40:	learn: 1561.3086134	total: 11.2s	remaining: 16.1s
# 41:	learn: 1554.5920914	total: 11.5s	remaining: 15.8s
# 42:	learn: 1548.6716392	total: 11.8s	remaining: 15.6s
# 43:	learn: 1542.8521791	total: 12s	remaining: 15.3s
# 44:	learn: 1537.9785914	total: 12.3s	remaining: 15s
# 45:	learn: 1532.4999072	total: 12.6s	remaining: 14.8s
# 46:	learn: 1528.2841009	total: 12.9s	remaining: 14.5s
# 47:	learn: 1522.9785260	total: 13.1s	remaining: 14.2s
# 48:	learn: 1519.1697498	total: 13.4s	remaining: 13.9s
# 49:	learn: 1512.9353479	total: 13.7s	remaining: 13.7s
# 50:	learn: 1510.0550868	total: 14s	remaining: 13.4s
# 51:	learn: 1507.2709384	total: 14.2s	remaining: 13.1s
# 52:	learn: 1504.8951739	total: 14.5s	remaining: 12.9s
# 53:	learn: 1501.1135021	total: 14.8s	remaining: 12.6s
# 54:	learn: 1498.4871906	total: 15s	remaining: 12.3s
# 55:	learn: 1495.5917897	total: 15.3s	remaining: 12s
# 56:	learn: 1490.6677419	total: 15.6s	remaining: 11.7s
# 57:	learn: 1487.7745485	total: 15.8s	remaining: 11.5s
# 58:	learn: 1485.4106611	total: 16.1s	remaining: 11.2s
# 59:	learn: 1482.8006061	total: 16.4s	remaining: 10.9s
# 60:	learn: 1478.9066835	total: 16.6s	remaining: 10.6s
# 61:	learn: 1476.0800679	total: 16.9s	remaining: 10.4s
# 62:	learn: 1474.0391793	total: 17.2s	remaining: 10.1s
# 63:	learn: 1472.5713209	total: 17.4s	remaining: 9.8s
# 64:	learn: 1469.7956529	total: 17.7s	remaining: 9.52s
# 65:	learn: 1464.8667087	total: 18s	remaining: 9.25s
# 66:	learn: 1463.2032156	total: 18.2s	remaining: 8.97s
# 67:	learn: 1461.1699072	total: 18.5s	remaining: 8.7s
# 68:	learn: 1458.6428297	total: 18.8s	remaining: 8.43s
# 69:	learn: 1454.4786444	total: 19s	remaining: 8.15s
# 70:	learn: 1452.7000620	total: 19.3s	remaining: 7.88s
# 71:	learn: 1449.8951536	total: 19.6s	remaining: 7.61s
# 72:	learn: 1446.8782666	total: 19.8s	remaining: 7.33s
# 73:	learn: 1445.1408205	total: 20.1s	remaining: 7.06s
# 74:	learn: 1442.9190582	total: 20.4s	remaining: 6.79s
# 75:	learn: 1440.1558728	total: 20.6s	remaining: 6.51s
# 76:	learn: 1437.4223956	total: 20.9s	remaining: 6.24s
# 77:	learn: 1436.3450588	total: 21.1s	remaining: 5.96s
# 78:	learn: 1434.5032493	total: 21.4s	remaining: 5.69s
# 79:	learn: 1433.0305505	total: 21.7s	remaining: 5.41s
# 80:	learn: 1431.2058881	total: 21.9s	remaining: 5.14s
# 81:	learn: 1429.2777229	total: 22.2s	remaining: 4.87s
# 82:	learn: 1427.7346402	total: 22.5s	remaining: 4.6s
# 83:	learn: 1426.5797957	total: 22.7s	remaining: 4.33s
# 84:	learn: 1423.0614953	total: 23s	remaining: 4.05s
# 85:	learn: 1420.8909320	total: 23.2s	remaining: 3.78s
# 86:	learn: 1416.3078954	total: 23.5s	remaining: 3.51s
# 87:	learn: 1413.4580261	total: 23.8s	remaining: 3.24s
# 88:	learn: 1411.8354890	total: 24.1s	remaining: 2.98s
# 89:	learn: 1408.8677364	total: 24.4s	remaining: 2.71s
# 90:	learn: 1404.6782723	total: 24.6s	remaining: 2.43s
# 91:	learn: 1401.3034963	total: 24.9s	remaining: 2.16s
# 92:	learn: 1398.4764486	total: 25.2s	remaining: 1.89s
# 93:	learn: 1396.6528434	total: 25.4s	remaining: 1.62s
# 94:	learn: 1395.7532616	total: 25.7s	remaining: 1.35s
# 95:	learn: 1394.6126107	total: 25.9s	remaining: 1.08s
# 96:	learn: 1390.2543137	total: 26.2s	remaining: 811ms
# 97:	learn: 1387.7670664	total: 26.5s	remaining: 541ms
# 98:	learn: 1385.8768841	total: 26.8s	remaining: 270ms
# 99:	learn: 1383.9396805	total: 27s	remaining: 0us
# Resultados de GridSearch
#
#  La mejor puntuación: -1593.9795911475646
#
#  Los mejores parámetros:
#  {'depth': 16, 'iterations': 100, 'learning_rate': 0.1}

# %% [markdown]
# Con estos parámetros se entrenará el modelo y se tomará el tiempo.

# %%
#fila con la información del modelo
cbr_info = ['CatBoostRegressor']

cbr_model = CatBoostRegressor(
    depth=best_param['depth'],
    iterations=best_param['iterations'],
    learning_rate=best_param['learning_rate']
)

#Tomar tiempo de entrenamiento
start = time.time()
cbr_model.fit(features_train, target_train, cat_features=categorical, verbose=False, plot=False)
end=time.time()

#agregar el tiempo de entrenamiento
cbr_info.append(end - start)

#Tomar tiempo de predicción
start = time.time()
cbr_predict = cbr_model.predict(features_test)
end=time.time()

#agregar el tiempo de predicción
cbr_info.append(end - start)

#RMSE
cbr_rmse = rmse(target_test, cbr_predict)

#add to row
cbr_info.append(cbr_rmse)

model_info.loc[len(model_info)] = cbr_info
model_info.head()
# Out:
#                model   fit_time  predict_time         rmse
# 0  Linear Regression   2.791132      0.027558  2688.063915
# 1      Decision Tree   2.387368      0.031758  1834.772587
# 2      Random Forest  85.885852      0.521819  1560.465073
# 3  CatBoostRegressor  27.360088      0.033150  1572.943566

# %% [markdown]
# Este modelo tiene un RECM mayor que el obtenido con el bosque aleatorio, sin embargo sus tiempos son menores.
#
# [Volver a Contenidos](#back)

# %% [markdown]
# ### 2. 5. LightGBM <a id='data_model_lightgbm'></a>
#
# En esta sección se utilizará LightGBM para entrenar el modelo. Lo primero que se debe hacer es convertir las variables categóricas al tipo correcto.

# %%
for item in categorical:
    features_train[item] = features_train[item].astype('category')
    features_test[item] = features_test[item].astype('category')

# %% [markdown]
# Así como con el anterior, se utilizarán diferentes parámetros y con GridSearchCV se encontrarán los mejores.

# %%
model=LGBMRegressor()

parameters = {
    'num_leaves': [40, 50, 60],
    'learning_rate': [0.5, 0.1],
    'n_estimators': [50, 60,70]
}

grid = GridSearchCV(estimator=model, param_grid=parameters, scoring=rmse_scorer, cv=3, n_jobs=-1)
grid.fit(features_train, target_train)
best_param=grid.best_params_

print('Resultados de GridSearch')
print("\n La mejor puntuación:", grid.best_score_)
print("\n Los mejores parámetros:\n", grid.best_params_)
# Out:
# Resultados de GridSearch
#
#  La mejor puntuación: -1578.17002080581
#
#  Los mejores parámetros:
#  {'learning_rate': 0.1, 'n_estimators': 70, 'num_leaves': 60}

# %% [markdown]
# Con estos parámetros se entrenará el modelo y se tomará el tiempo.

# %%
#fila con la información del modelo
lgbm_info = ['LightGBMRegressor']

lgbm_model = LGBMRegressor(
    learning_rate=best_param['learning_rate'],
    n_estimators=best_param['n_estimators'],
    num_leaves=best_param['num_leaves']
)

#Tomar tiempo de entrenamiento
start = time.time()
lgbm_model.fit(features_train, target_train)
end=time.time()

#agregar el tiempo de entrenamiento
lgbm_info.append(end - start)

#Tomar tiempo de predicción
start = time.time()
lgbm_predict = lgbm_model.predict(features_test)
end=time.time()

#agregar el tiempo de predicción
lgbm_info.append(end - start)

#RMSE
lgbm_rmse = rmse(target_test, lgbm_predict)

#add to row
lgbm_info.append(lgbm_rmse)

model_info.loc[len(model_info)] = lgbm_info
model_info.head()
# Out:
#                model   fit_time  predict_time         rmse
# 0  Linear Regression   2.791132      0.027558  2688.063915
# 1      Decision Tree   2.387368      0.031758  1834.772587
# 2      Random Forest  85.885852      0.521819  1560.465073
# 3  CatBoostRegressor  27.360088      0.033150  1572.943566
# 4  LightGBMRegressor   0.398182      0.053457  1569.640920

# %% [markdown]
# Este modelo tiene menor tiempo de entrenamiento aunque el RECM es mayor que el de bosque aleatorio.
#
# [Volver a Contenidos](#back)

# %% [markdown]
# ### 2. 6. Conclusiones <a id='data_model_conclusions'></a>
#
# En esta etapa se entrenaron modelos usando los algoritmos: regresión lineal, árbol de decisión, bosque aleatorio, CatBoost y LightGBM.
#
# Se utilizaron diferentes hiperparámetros para cada uno de ellos y utilizando validación cruzada, o bien, GridSearchCV, se decidió cuales eran los mejores.
#
# Con esto parámetros se entrenaron los diferentes modelos y se tomaron los tiempos tanto de entrenamiento como de predicción. La métrica de evaluación fue el RECM.
#
# [Volver a Contenidos](#back)

# %% [markdown]
# ## Etapa 3. Análisis del modelo <a id='data_analysis'></a>
#
# Se imprimirá nuevamente la información de los modelos, obtenida en la etapa anterior.

# %%
model_info
# Out:
#                model   fit_time  predict_time         rmse
# 0  Linear Regression   2.791132      0.027558  2688.063915
# 1      Decision Tree   2.387368      0.031758  1834.772587
# 2      Random Forest  85.885852      0.521819  1560.465073
# 3  CatBoostRegressor  27.360088      0.033150  1572.943566
# 4  LightGBMRegressor   0.398182      0.053457  1569.640920

# %% [markdown]
# Tenemos que el modelo con el menor RECM es el entrenado con el algoritmo del bosque aleatorio, mientras que la regresión lineal resulta en el mayor valor de RECM. Sin embargo, este modelo funciona como una prueba de cordura.
#
# Por otro lado, el bosque aleatorio es el que presenta mayor tiempo de entrenamiento, de hecho, la diferencia es muy grande comparado con todos lode demás modelos.
#
# El modelo basado en LightGBMRegressor es el que presenta el mejor tiempo de entrenamiento y aunque ocupa el cuarto lugar con respecto al tiempo de predicción, la diferencia es mínima con respecto a los primeros tres lugares. Además, es el modelo que ocupa el segundo lugar con respecto al RECM (de menor a mayor).
#
# Por lo tanto, el modelo basado en LightGBMRegressor es el mejor pues registra buenas puentuaciones tanto en RECM como en tiempos.
#
# [Volver a Contenidos](#back)

# %% [markdown]
# ## Etapa 4. Conclusión general <a id='data_conclusion'></a>
#
# En la primera etapa se preprocesaron los datos, en primer lugar se renombraron las columnas del dataset conforme a la nomenclatura convencional y se cambiaron los datos correspondientes a formato fecha. Se reemplazron valores ausentes en la columna sobre la información de reparaciones con `'unknown'` y se eliminaron las filas que tenían valores ausentes en las demás columnas.
#
# En la segunda etapa se entrenaron modelos utilizando cinco algoritmos diferentes. Se variaron los hiperpárametros y con validación cruzada o con GridSearchCV se elegieron los mejores. También se midieron los tiempos de entrenamiento y predicción.
#
# En la tercera etapa se analizó la calidad de los modelos, tomando en cuenta tanto la métrica RECM como los tiempos obtenidos en la segunda etapa. El modelo con las mejores puntuaciones en cuanto a tiempo fue el realizado con LightGBMRegressor. Además, registró el segundo mejor valor de RECM. Por esta razón se concluyó que es el modelo más apropiado tomando en cuenta los requerimientos del cliente.
#
# [Volver a Contenidos](#back)
